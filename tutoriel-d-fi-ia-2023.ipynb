# %% [markdown]
# # Tutoriel d'usage de l'API

# %%
import pandas
import numpy as np

Features = pandas.read_csv('features_hotels.csv')
Features
#Features['city'][]
# Out:
#      hotel_id               group          brand        city  parking  pool  \
# 0           0            Yin Yang    Royal Lotus       paris        1     0
# 1           1         Independant    Independant  copenhagen        1     0
# 2           2         Independant    Independant      madrid        0     0
# 3           3         Independant    Independant        rome        1     0
# 4           4         Independant    Independant       sofia        1     0
# ..        ...                 ...            ...         ...      ...   ...
# 994       994            Yin Yang       Ardisson  copenhagen        0     0
# 995       995  Chillton Worldwide  Quadrupletree  copenhagen        0     0
# 996       996        Accar Hotels        Navatel      vienna        0     0
# 997       997  Chillton Worldwide     Tripletree      madrid        0     0
# 998       998            Yin Yang    Royal Lotus       paris        0     0
#
#      children_policy
# 0                  1
# ...

# %%
city = Features['city'].unique()

# %%
Test = pandas.read_csv('test_set.csv')
Test
# Out:
#       index  order_requests     city  date  language  mobile  avatar_id  \
# 0         0               1  vilnius    21  romanian       0          1
# 1         1               1  vilnius    21  romanian       0          1
# 2         2               1  vilnius    21  romanian       0          1
# 3         3               1  vilnius    21  romanian       0          1
# 4         4               1  vilnius    21  romanian       0          1
# ...     ...             ...      ...   ...       ...     ...        ...
# 6639   6639             843     rome     5     irish       0        794
# 6640   6640             844   vienna     1     irish       1        794
# 6641   6641             844   vienna     1     irish       1        794
# 6642   6642             844   vienna     1     irish       1        794
# 6643   6643             844   vienna     1     irish       1        794
#
#       hotel_id  stock
# 0          161     46
# 1          187     32
# 2          279     12
# ...

# %%
np.shape(city)
# Out:
# (9,)

# %%
language = Test['language'].unique()
language
# Out:
# array(['romanian', 'swedish', 'maltese', 'belgian', 'luxembourgish',
#        'dutch', 'french', 'finnish', 'austrian', 'slovakian', 'hungarian',
#        'bulgarian', 'danish', 'greek', 'croatian', 'polish', 'german',
#        'spanish', 'estonian', 'lithuanian', 'cypriot', 'latvian', 'irish',
#        'italian', 'slovene', 'czech', 'portuguese'], dtype=object)

# %%
np.shape(language)[0]
# Out:
# 27

# %%
import random

# %%
a = random.randint(-2,2)
a
# Out:
# 0

# %%
import requests
import pandas as pd
user_id = '0965ef50-4892-4e22-923c-236be6b36411'

# %%
'''matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

for h in range(1):
    for i in range(1):
        for j in range(1):
            for k in range(np.shape(city)[0]):
                a = random.randint(-2,2)
                name = "test2_avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
                params = {
                    "avatar_name": name ,
                    "language": language[j],
                    "city": city[k],
                    "date": date[i] + a,
                    "mobile": mobile[h],    
                }
                compteur +=1
                print(params)
    
                r1 = requests.post(path(f"avatars/{user_id}/{name}"))
                r1 = requests.get(path(f"pricing/{user_id}"), params=params)
                pricing_requests.append(
                    pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
                )
                df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
                matrix_avatar = matrix_avatar.append(df_tmp)
                
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)'''
# Out:
# {'avatar_name': 'test2_avatar_d36_step7j_0_975', 'language': 'romanian', 'city': 'paris', 'date': 36, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d38_step7j_0_976', 'language': 'romanian', 'city': 'copenhagen', 'date': 38, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d37_step7j_0_977', 'language': 'romanian', 'city': 'madrid', 'date': 37, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d35_step7j_0_978', 'language': 'romanian', 'city': 'rome', 'date': 35, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d36_step7j_0_979', 'language': 'romanian', 'city': 'sofia', 'date': 36, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d37_step7j_0_980', 'language': 'romanian', 'city': 'vilnius', 'date': 37, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d38_step7j_0_981', 'language': 'romanian', 'city': 'vienna', 'date': 38, 'mobile': 0}
# {'avatar_name': 'test2_avatar_d38_step7j_0_982', 'language': 'romanian', 'city': 'amsterdam', 'date': 38, 'mobile': 0}
# ...

# %%
matrix_merge.to_csv('matrix_merge.csv')

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])

# %%
pricing_requests = []
pricing_requests.append(
                    pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
                )
df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
matrix_avatar = matrix_avatar.append(df_tmp)

# %%
pricing_requests = pd.concat(pricing_requests)
pricing_requests.head()
# Out:
#    hotel_id  price  stock   city  date  language  mobile  avatar_id
# 0        95    250    174  paris    35  romanian       0      38458
# 1       884    175    111  paris    35  romanian       0      38458
# 2       579     79     35  paris    35  romanian       0      38458
# 3       684     80     32  paris    35  romanian       0      38458
# 4       825    161     80  paris    35  romanian       0      38458

# %%
pd.DataFrame(matrix_avatar)
# Out:
#   avatar_id                          name
# 0     38458  test_avatar_d35_step7j_0_973

# %%
matrix_merge = pd.merge(pricing_requests,matrix_avatar)
matrix_merge
# Out:
#      hotel_id  price  stock   city  date  language  mobile avatar_id  \
# 0          95    250    174  paris    35  romanian       0     38458
# 1         884    175    111  paris    35  romanian       0     38458
# 2         579     79     35  paris    35  romanian       0     38458
# 3         684     80     32  paris    35  romanian       0     38458
# 4         825    161     80  paris    35  romanian       0     38458
# ..        ...    ...    ...    ...   ...       ...     ...       ...
# 151       741    169     76  paris    35  romanian       0     38458
# 152       735    111     59  paris    35  romanian       0     38458
# 153       885    170     74  paris    35  romanian       0     38458
# 154       379    261    162  paris    35  romanian       0     38458
# 155       558     84     31  paris    35  romanian       0     38458
#
#                              name
# 0    test_avatar_d35_step7j_0_973
# 1    test_avatar_d35_step7j_0_973
# ...

# %%
display(r1.json())
# Out:
# {'prices': [{'hotel_id': 95, 'price': 250, 'stock': 174},
#   {'hotel_id': 884, 'price': 175, 'stock': 111},
#   {'hotel_id': 579, 'price': 79, 'stock': 35},
#   {'hotel_id': 684, 'price': 80, 'stock': 32},
#   {'hotel_id': 825, 'price': 161, 'stock': 80},
#   {'hotel_id': 560, 'price': 153, 'stock': 78},
#   {'hotel_id': 323, 'price': 269, 'stock': 155},
#   {'hotel_id': 912, 'price': 164, 'stock': 73},
#   {'hotel_id': 842, 'price': 287, 'stock': 143},
#   {'hotel_id': 130, 'price': 181, 'stock': 104},
#   {'hotel_id': 526, 'price': 265, 'stock': 155},
#   {'hotel_id': 419, 'price': 106, 'stock': 67},
#   {'hotel_id': 299, 'price': 108, 'stock': 76},
#   {'hotel_id': 314, 'price': 115, 'stock': 62},
#   {'hotel_id': 631, 'price': 80, 'stock': 32},
#   {'hotel_id': 199, 'price': 196, 'stock': 104},
#   {'hotel_id': 866, 'price': 251, 'stock': 171},
#   {'hotel_id': 975, 'price': 159, 'stock': 72},
#   {'hotel_id': 222, 'price': 250, 'stock': 150},
# ...

# %%
for r in requests:
    pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

pricing_requests = pd.concat(pricing_requests)
pricing_requests.head()

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %%
'''#Premier script 
compteur = 0
i = 0
step = ['step7j_','step3j_']

# MOBILE 0, départ 36e jour avec step 7 jours
date = [36,16]
mobile = [0,1]

matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

for h in range(2):
    for i in range(2):
        for j in range(np.shape(language)[0]):
            for k in range(np.shape(city)[0]):
                a = random.randint(-2,2)
                name = "avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
                params = {
                    "avatar_name": name ,
                    "language": language[j],
                    "city": city[k],
                    "date": date[i] + a,
                    "mobile": mobile[h],    
                }
                compteur +=1
                print(params)
    
                r1 = requests.post(path(f"avatars/{user_id}/{name}"))
                r1 = requests.get(path(f"pricing/{user_id}"), params=params)
                pricing_requests.append(
                    pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
                )
                df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
                matrix_avatar = matrix_avatar.append(df_tmp)
                
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)
matrix_merge.to_csv('matrix_merge.csv')'''
# Out:
# {'avatar_name': 'avatar_d35_step7j_0_0', 'language': 'romanian', 'city': 'paris', 'date': 35, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_1', 'language': 'romanian', 'city': 'copenhagen', 'date': 36, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_2', 'language': 'romanian', 'city': 'madrid', 'date': 37, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_3', 'language': 'romanian', 'city': 'rome', 'date': 34, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_4', 'language': 'romanian', 'city': 'sofia', 'date': 38, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_5', 'language': 'romanian', 'city': 'vilnius', 'date': 38, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_6', 'language': 'romanian', 'city': 'vienna', 'date': 36, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_7', 'language': 'romanian', 'city': 'amsterdam', 'date': 35, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_8', 'language': 'romanian', 'city': 'valletta', 'date': 37, 'mobile': 0}
# ...

# %%
matrix_merge.to_csv('matrix_merge.csv')

# %%
matrix_merge
# Out:
#         hotel_id  price  stock      city  date    language  mobile avatar_id  \
# 0            663    149     84     paris    35    romanian       0     38715
# 1            912    164     73     paris    35    romanian       0     38715
# 2            640    152     70     paris    35    romanian       0     38715
# 3            656    106     64     paris    35    romanian       0     38715
# 4            792     82     76     paris    35    romanian       0     38715
# ...          ...    ...    ...       ...   ...         ...     ...       ...
# 100934       491    167     24  valletta    15  portuguese       1     39686
# 100935       371    100      3  valletta    15  portuguese       1     39686
# 100936       334     82      5  valletta    15  portuguese       1     39686
# 100937       466    169     14  valletta    15  portuguese       1     39686
# 100938       389    121      2  valletta    15  portuguese       1     39686
#
#                            name
# ...

# %%
for i in range(10)

# %%
list = []
for i in range(np.shape(Features['city'])[0]):

# %%
import csv

with open('features_hotels.csv') as File:  
    Line_reader = csv.reader(File)

# %% [markdown]
# ## Creating an avatar

# %% [markdown]
# The admin of the competition can create users. A user can then create as many avatars as they wish.

# %%
name = 'test-first-avatar'
r = requests.post(path(f'avatars/{user_id}/{name}'))
r
# Out:
# <Response [409]>

# %%
name = 'test-second-avatar'
r = requests.post(path(f"avatars/{user_id}/{name}"))
r
# Out:
# <Response [409]>

# %%
r = requests.get(path(f"avatars/{user_id}"))
for avatar in r.json():
    print(avatar['id'], avatar['name'])
# Out:
# 28468 test-first-avatar
# 28469 test-second-avatar

# %%
avatar['name']
# Out:
# 'test-second-avatar'

# %%
import pandas as pd
matrix_avatar = []
matrix_avatar = pd.DataFrame([],columns = ['id', 'name','order_request','city','date','mobile','language','stock','index'])

# %%
for avatar in r.json():
    df_tmp = pd.DataFrame([(avatar['id'],avatar['name'])], columns=['id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)

# %%
matrix_avatar
# Out:
#       id                name order_request city date mobile language stock  \
# 0  28468   test-first-avatar           NaN  NaN  NaN    NaN      NaN   NaN
# 0  28469  test-second-avatar           NaN  NaN  NaN    NaN      NaN   NaN
#
#   index
# 0   NaN
# 0   NaN

# %% [markdown]
# ## Making pricing requests

# %%
params = np.zeros(100)
langue = ['english','hungarian','spanish','french']
for i in range(100):
    avatar = 
params[i] = {
    "avatar_name": "avatar_"+str(i),
    "language": langue[],
    "city": "copenhagen",
    "date": 2,
    "mobile": 0,    
}
fsmsdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-60024bfb6411> in <module>
#       2
#       3 }
# ----> 4 params.type()
#
# AttributeError: 'dict' object has no attribute 'type'

# %%
params = np.zeros(100)
langue = ['english','hungarian','spanish','french']


for i in range(100):
    avatar = "avatar_"+str(i)
    langue = 
    city = 
    mobile = 
    date = 
    params = {
        "avatar_name": avatar,
        "language": langue,
        "city": city,
        "date": date,
        "mobile": mobile,    
    }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-60024bfb6411> in <module>
#       2
#       3 }
# ----> 4 params.type()
#
# AttributeError: 'dict' object has no attribute 'type'

# %%
params = {
    "avatar_name": "max-first-avatar",
    "language": "hungarian",
    "city": "copenhagen",
    "date": 2,
    "mobile": 0,
}
r1 = requests.get(path(f"pricing/{user_id}"), params=params)
r1.json()
# Out:
# {'prices': [{'hotel_id': 720, 'price': 467, 'stock': 2},
#   {'hotel_id': 434, 'price': 114, 'stock': 0},
#   {'hotel_id': 349, 'price': 317, 'stock': 1},
#   {'hotel_id': 367, 'price': 96, 'stock': 0},
#   {'hotel_id': 952, 'price': 94, 'stock': 0},
#   {'hotel_id': 528, 'price': 432, 'stock': 2},
#   {'hotel_id': 990, 'price': 168, 'stock': 0},
#   {'hotel_id': 60, 'price': 94, 'stock': 0},
#   {'hotel_id': 834, 'price': 91, 'stock': 0},
#   {'hotel_id': 757, 'price': 151, 'stock': 1},
#   {'hotel_id': 531, 'price': 204, 'stock': 2},
#   {'hotel_id': 772, 'price': 327, 'stock': 0},
#   {'hotel_id': 664, 'price': 472, 'stock': 2},
#   {'hotel_id': 332, 'price': 333, 'stock': 1},
#   {'hotel_id': 113, 'price': 89, 'stock': 0},
#   {'hotel_id': 445, 'price': 89, 'stock': 0},
#   {'hotel_id': 695, 'price': 202, 'stock': 2},
#   {'hotel_id': 142, 'price': 390, 'stock': 4},
#   {'hotel_id': 547, 'price': 202, 'stock': 2},
#   {'hotel_id': 793, 'price': 167, 'stock': 0},
# ...

# %% [markdown]
# ## Build a training set

# %%
hotels = pd.read_csv('../input/defi-ia-2023/features_hotels.csv', index_col=['hotel_id', 'city'])
pricing_requests = pricing_requests.join(hotels, on=['hotel_id', 'city'])
pricing_requests.head()
# Out:
#    hotel_id  price  stock        city  date   language  mobile  avatar_id  \
# 0       720    467      2  copenhagen     2  hungarian       0          5
# 1       434    114      0  copenhagen     2  hungarian       0          5
# 2       349    317      1  copenhagen     2  hungarian       0          5
# 3       367     96      0  copenhagen     2  hungarian       0          5
# 4       952     94      0  copenhagen     2  hungarian       0          5
#
#                 group             brand  parking  pool  children_policy
# 0  Chillton Worldwide  Chill Garden Inn        0     0                2
# 1        Accar Hotels              Ibas        0     0                0
# 2            Yin Yang       Royal Lotus        0     1                0
# 3            Yin Yang         8 Premium        0     0                0
# 4         Independant       Independant        0     0                0

# %%
sample_submission = pd.read_csv('../input/defi-ia-2023/sample_submission.csv')
sample_submission.head()
# Out:
#    index  price
# 0      0  191.0
# 1      1  191.0
# 2      2  191.0
# 3      3  191.0
# 4      4  191.0

# %% [markdown]
# # Nouvelles requests

# %% [markdown]
# ## Request 1

# %%
import pandas as pd
requests = pd.read_csv('matrix_merge.csv')

# %%
display(requests)
# Out:
#         Unnamed: 0  hotel_id  price  stock      city  date    language  \
# 0                0       663    149     84     paris    35    romanian
# 1                1       912    164     73     paris    35    romanian
# 2                2       640    152     70     paris    35    romanian
# 3                3       656    106     64     paris    35    romanian
# 4                4       792     82     76     paris    35    romanian
# ...            ...       ...    ...    ...       ...   ...         ...
# 100934      100934       491    167     24  valletta    15  portuguese
# 100935      100935       371    100      3  valletta    15  portuguese
# 100936      100936       334     82      5  valletta    15  portuguese
# 100937      100937       466    169     14  valletta    15  portuguese
# 100938      100938       389    121      2  valletta    15  portuguese
#
#         mobile  avatar_id                     name
# 0            0      38715    avatar_d35_step7j_0_0
# ...

# %%
requests['name'=='avatar_d15_step3j_1_971']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ac94cac38d95> in <module>
# ----> 1 requests['name'=='avatar_d15_step3j_1_971']
#
# ...

# %%
liste_titres
# Out:
# ['avatar_d35_step7j_0_0',
#  'avatar_d36_step7j_0_1',
#  'avatar_d37_step7j_0_2',
#  'avatar_d34_step7j_0_3',
#  'avatar_d38_step7j_0_4',
#  'avatar_d38_step7j_0_5',
#  'avatar_d36_step7j_0_6',
#  'avatar_d35_step7j_0_7',
#  'avatar_d37_step7j_0_8',
#  'avatar_d37_step7j_0_9',
#  'avatar_d35_step7j_0_10',
#  'avatar_d37_step7j_0_11',
#  'avatar_d35_step7j_0_12',
#  'avatar_d35_step7j_0_13',
#  'avatar_d34_step7j_0_14',
#  'avatar_d35_step7j_0_15',
#  'avatar_d36_step7j_0_16',
#  'avatar_d37_step7j_0_17',
#  'avatar_d35_step7j_0_18',
#  'avatar_d38_step7j_0_19',
#  'avatar_d36_step7j_0_20',
#  'avatar_d35_step7j_0_21',
#  'avatar_d38_step7j_0_22',
#  'avatar_d35_step7j_0_23',
#  'avatar_d35_step7j_0_24',
#  'avatar_d36_step7j_0_25',
#  'avatar_d34_step7j_0_26',
#  'avatar_d34_step7j_0_27',
#  'avatar_d36_step7j_0_28',
#  'avatar_d35_step7j_0_29',
#  'avatar_d34_step7j_0_30',
#  'avatar_d36_step7j_0_31',
#  'avatar_d38_step7j_0_32',
#  'avatar_d37_step7j_0_33',
# ...

# %%
for i in requests['name'].unique() :
        print(requests['date'])
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-09a873d66f6d> in <module>
#       1 for i in requests['name'].unique() :
# ----> 2     if requests['avatar_id']==i :
#       3         print(requests['date'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
inf30 = requests['date']>30
sup40 = requests['date']<40
display(inf30)
andd = pd.DataFrame(inf30*sup40)
andd
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 100934    False
# 100935    False
# 100936    False
# 100937    False
# 100938    False
# Name: date, Length: 100939, dtype: bool
# C:\Users\elise\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:194: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   op=op_str, alt_op=unsupported[op_str]
#          date
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 100934  False
# 100935  False
# 100936  False
# 100937  False
# 100938  False
#
# [100939 rows x 1 columns]

# %%
requests['date'].unique()
# Out:
# array([35, 36, 37, 34, 38, 15, 16, 17, 18, 14], dtype=int64)

# %%
new_requests = pd.DataFrame(requests['hotel_id', 'price', 'stock', 'city', 'date', 'language', 'mobile', 'avatar_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('hotel_id', 'price', 'stock', 'city', 'date', 'language', 'mobile', 'avatar_id')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
new_requests
# Out:
#           0       1       2       3       4       5       6       7       \
# hotel_id     663     912     640     656     792     165     148     645
# price        149     164     152     106      82     151     114     157
#
#           8       9       ...  100929  100930  100931  100932  100933  100934  \
# hotel_id     579     308  ...     749     965     400     832     905     491
# price         79     192  ...     125     165      99     160     165     167
#
#           100935  100936  100937  100938
# hotel_id     371     334     466     389
# price        100      82     169     121
#
# [2 rows x 100939 columns]

# %%
new_matrix = pd.DataFrame(requests['name'].unique(),columns = ['name'])

# %%
display(new_matrix)
# Out:
#                         name
# 0      avatar_d35_step7j_0_0
# 1      avatar_d36_step7j_0_1
# 2      avatar_d37_step7j_0_2
# 3      avatar_d34_step7j_0_3
# 4      avatar_d38_step7j_0_4
# ..                       ...
# 967  avatar_d17_step3j_1_967
# 968  avatar_d15_step3j_1_968
# 969  avatar_d14_step3j_1_969
# 970  avatar_d17_step3j_1_970
# 971  avatar_d15_step3j_1_971
#
# [972 rows x 1 columns]

# %%
visualisation = pd.merge(new_matrix,requests, copy = False)

# %%
display(requests)
# Out:
#         Unnamed: 0  hotel_id  price  stock      city  date    language  \
# 0                0       663    149     84     paris    35    romanian
# 1                1       912    164     73     paris    35    romanian
# 2                2       640    152     70     paris    35    romanian
# 3                3       656    106     64     paris    35    romanian
# 4                4       792     82     76     paris    35    romanian
# ...            ...       ...    ...    ...       ...   ...         ...
# 100934      100934       491    167     24  valletta    15  portuguese
# 100935      100935       371    100      3  valletta    15  portuguese
# 100936      100936       334     82      5  valletta    15  portuguese
# 100937      100937       466    169     14  valletta    15  portuguese
# 100938      100938       389    121      2  valletta    15  portuguese
#
#         mobile  avatar_id                     name
# 0            0      38715    avatar_d35_step7j_0_0
# ...

# %%
subset_requests = requests[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
# Out:
#                            name  avatar_id  date    language  mobile  \
# 0         avatar_d35_step7j_0_0      38715    35    romanian       0
# 156       avatar_d36_step7j_0_1      38716    36    romanian       0
# 291       avatar_d37_step7j_0_2      38717    37    romanian       0
# 399       avatar_d34_step7j_0_3      38718    34    romanian       0
# 521       avatar_d38_step7j_0_4      38719    38    romanian       0
# ...                         ...        ...   ...         ...     ...
# 100525  avatar_d17_step3j_1_967      39682    17  portuguese       1
# 100576  avatar_d15_step3j_1_968      39683    15  portuguese       1
# 100663  avatar_d14_step3j_1_969      39684    14  portuguese       1
# 100769  avatar_d17_step3j_1_970      39685    17  portuguese       1
# 100893  avatar_d15_step3j_1_971      39686    15  portuguese       1
#
#               city
# 0            paris
# 156     copenhagen
# 291         madrid
# 399           rome
# 521          sofia
# ...

# %%
date_plus_30j = visualisation[(visualisation["date"] >30)]
date_inf_20j = visualisation[(visualisation["date"] < 20)]

# %%
date_plus_30j["date"] = date_plus_30j["date"] - 7
date_inf_20j["date"] = date_inf_20j["date"] - 3
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
display(date_plus_30j)
display(date_inf_20j)
# Out:
#                           name  avatar_id  date    language  mobile  \
# 0        avatar_d35_step7j_0_0      38715    21    romanian       0
# 156      avatar_d36_step7j_0_1      38716    22    romanian       0
# 291      avatar_d37_step7j_0_2      38717    23    romanian       0
# 399      avatar_d34_step7j_0_3      38718    20    romanian       0
# 521      avatar_d38_step7j_0_4      38719    24    romanian       0
# ...                        ...        ...   ...         ...     ...
# 75103  avatar_d38_step7j_1_724      39439    24  portuguese       1
# 75156  avatar_d37_step7j_1_725      39440    23  portuguese       1
# 75242  avatar_d34_step7j_1_726      39441    20  portuguese       1
# 75340  avatar_d35_step7j_1_727      39442    21  portuguese       1
# 75465  avatar_d37_step7j_1_728      39443    23  portuguese       1
#
#              city
# 0           paris
# 156    copenhagen
# 291        madrid
# 399          rome
# 521         sofia
# ...           ...
# ...

# %%
frames = [date_plus_30j, date_inf_20j]
result = pd.concat(frames)
display(result)
# Out:
#                            name  avatar_id  date    language  mobile  \
# 0         avatar_d35_step7j_0_0      38715    21    romanian       0
# 156       avatar_d36_step7j_0_1      38716    22    romanian       0
# 291       avatar_d37_step7j_0_2      38717    23    romanian       0
# 399       avatar_d34_step7j_0_3      38718    20    romanian       0
# 521       avatar_d38_step7j_0_4      38719    24    romanian       0
# ...                         ...        ...   ...         ...     ...
# 100525  avatar_d17_step3j_1_967      39682    14  portuguese       1
# 100576  avatar_d15_step3j_1_968      39683    12  portuguese       1
# 100663  avatar_d14_step3j_1_969      39684    11  portuguese       1
# 100769  avatar_d17_step3j_1_970      39685    14  portuguese       1
# 100893  avatar_d15_step3j_1_971      39686    12  portuguese       1
#
#               city
# 0            paris
# 156     copenhagen
# 291         madrid
# 399           rome
# 521          sofia
# ...

# %%
import requests
import pandas as pd
user_id = '0965ef50-4892-4e22-923c-236be6b36411'

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

compteur = 0
for i in range(result.shape[0]):
#for i in range(1):
    params = {"avatar_name": result.iloc[i]['name'] ,
                "language": result.iloc[i]['language'],
                "city": result.iloc[i]['city'],
                "date": result.iloc[i]['date'],
                "mobile": result.iloc[i]['mobile'],    
                }
    #print(params)
    compteur += 1
    
    #avatar_id = result.iloc[i]['avatar_id']
    #r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    
print(compteur)

pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge_2 = pd.merge(pricing_requests,matrix_avatar_df)
matrix_merge_2.to_csv('matrix_merge_2.csv')
display(matrix_merge_2)
# Out:
# 972
#         hotel_id  price  stock      city  date    language  mobile avatar_id  \
# 0            785    204     21     paris    21    romanian       0     38715
# 1            323    284     58     paris    21    romanian       0     38715
# 2            972    101      8     paris    21    romanian       0     38715
# 3            705    144     18     paris    21    romanian       0     38715
# 4            357    163     25     paris    21    romanian       0     38715
# ...          ...    ...    ...       ...   ...         ...     ...       ...
# 104709       325    102      0  valletta    12  portuguese       1     39686
# 104710        81    166     12  valletta    12  portuguese       1     39686
# 104711       466    169      9  valletta    12  portuguese       1     39686
# 104712       719    213     15  valletta    12  portuguese       1     39686
# 104713       965    166     12  valletta    12  portuguese       1     39686
#
#                            name
# ...

# %%
visualisation.to_csv('nos_avatars.csv')

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

for h in range(2):
    for i in range(2):
        for j in range(np.shape(language)[0]):
            for k in range(np.shape(city)[0]):
                a = random.randint(-2,2)
                name = "avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
                params = {
                    "avatar_name": name[k] ,
                    "language": language[j],
                    "city": city[k],
                    "date": date[i] + a,
                    "mobile": mobile[h],    
                }
                compteur +=1
                print(params)
    
                #r1 = requests.post(path(f"avatars/{user_id}/{name}"))
                #r1 = requests.get(path(f"pricing/{user_id}"), params=params)
                #pricing_requests.append(
                #    pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
                #)
                #df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
                #matrix_avatar = matrix_avatar.append(df_tmp)
                
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)
matrix_merge.to_csv('matrix_merge.csv')

# %% [markdown]
# ## Request 2

# %%
import pandas as pd
requests = pd.read_csv('nos_avatars.csv')

# %%
display(requests)
# Out:
#      Unnamed: 0                     name  avatar_id  date    language  mobile  \
# 0             0    avatar_d35_step7j_0_0      38715    35    romanian       0
# 1           156    avatar_d36_step7j_0_1      38716    36    romanian       0
# 2           291    avatar_d37_step7j_0_2      38717    37    romanian       0
# 3           399    avatar_d34_step7j_0_3      38718    34    romanian       0
# 4           521    avatar_d38_step7j_0_4      38719    38    romanian       0
# ..          ...                      ...        ...   ...         ...     ...
# 967      100525  avatar_d17_step3j_1_967      39682    17  portuguese       1
# 968      100576  avatar_d15_step3j_1_968      39683    15  portuguese       1
# 969      100663  avatar_d14_step3j_1_969      39684    14  portuguese       1
# 970      100769  avatar_d17_step3j_1_970      39685    17  portuguese       1
# 971      100893  avatar_d15_step3j_1_971      39686    15  portuguese       1
#
#            city
# ...

# %%
requests['date'].unique()
# Out:
# array([35, 36, 37, 34, 38, 15, 16, 17, 18, 14], dtype=int64)

# %%
subset_requests = requests[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    35    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    36    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    37    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    34    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    38    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682    17  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683    15  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684    14  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685    17  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686    15  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
date_plus_30j = visualisation[(visualisation["date"] > 30)]
date_inf_20j = visualisation[(visualisation["date"] < 20)]

# %%
display(date_plus_30j)
display(date_inf_20j)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    35    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    36    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    37    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    34    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    38    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 724  avatar_d38_step7j_1_724      39439    38  portuguese       1       sofia
# 725  avatar_d37_step7j_1_725      39440    37  portuguese       1     vilnius
# 726  avatar_d34_step7j_1_726      39441    34  portuguese       1      vienna
# 727  avatar_d35_step7j_1_727      39442    35  portuguese       1   amsterdam
# 728  avatar_d37_step7j_1_728      39443    37  portuguese       1    valletta
#
# [486 rows x 6 columns]
# ...

# %%
date_plus_30j["date"] = date_plus_30j["date"] - 7*3
date_inf_20j["date"] = date_inf_20j["date"] - 3*3
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
display(date_plus_30j)
display(date_inf_20j)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    14    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    15    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    16    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    13    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    17    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 724  avatar_d38_step7j_1_724      39439    17  portuguese       1       sofia
# 725  avatar_d37_step7j_1_725      39440    16  portuguese       1     vilnius
# 726  avatar_d34_step7j_1_726      39441    13  portuguese       1      vienna
# 727  avatar_d35_step7j_1_727      39442    14  portuguese       1   amsterdam
# 728  avatar_d37_step7j_1_728      39443    16  portuguese       1    valletta
#
# [486 rows x 6 columns]
# ...

# %%
frames = [date_plus_30j, date_inf_20j]
result = pd.concat(frames)
display(result)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    14    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    15    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    16    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    13    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    17    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     8  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     6  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684     5  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     8  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     6  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
result['date'].unique()
# Out:
# array([14, 15, 16, 13, 17,  6,  7,  8,  9,  5], dtype=int64)

# %%
display(result)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    14    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    15    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    16    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    13    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    17    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     8  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     6  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684     5  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     8  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     6  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
import requests
import pandas as pd
user_id = '0965ef50-4892-4e22-923c-236be6b36411'

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

compteur = 0
for i in range(result.shape[0]):
#for i in range(1):
    params = {"avatar_name": result.iloc[i]['name'] ,
                "language": result.iloc[i]['language'],
                "city": result.iloc[i]['city'],
                "date": result.iloc[i]['date'],
                "mobile": result.iloc[i]['mobile'],    
                }
    #print(params)
    compteur += 1

    #avatar_id = result.iloc[i]['avatar_id']
    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],result.iloc[i]['name'])], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    
print(compteur)

pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge_3 = pd.merge(pricing_requests,matrix_avatar_df)
matrix_merge_3.to_csv('matrix_merge_3.csv')
display(matrix_merge_3)
# Out:
# 972
#         hotel_id  price  stock      city  date    language  mobile avatar_id  \
# 0            447    142      9     paris    14    romanian       0     38715
# 1            560    160     20     paris    14    romanian       0     38715
# 2            634     91      0     paris    14    romanian       0     38715
# 3             29    275     12     paris    14    romanian       0     38715
# 4            656    127     10     paris    14    romanian       0     38715
# ...          ...    ...    ...       ...   ...         ...     ...       ...
# 103516        55    126      0  valletta     6  portuguese       1     39686
# 103517       746    165      9  valletta     6  portuguese       1     39686
# 103518       512    270      4  valletta     6  portuguese       1     39686
# 103519       639    210      4  valletta     6  portuguese       1     39686
# 103520       377    143      0  valletta     6  portuguese       1     39686
#
#                            name
# ...

# %%
display(pricing_requests)
# Out:
# []
