# %% [markdown]
# # DEFI IA 2023

# %%
import numpy as np
import pandas as pd
import requests
import random

# %% [markdown]
# ### Display data

# %%
Features = pd.read_csv('features_hotels.csv')
Features
# Out:
#      hotel_id               group          brand        city  parking  pool  \
# 0           0            Yin Yang    Royal Lotus       paris        1     0
# 1           1         Independant    Independant  copenhagen        1     0
# 2           2         Independant    Independant      madrid        0     0
# 3           3         Independant    Independant        rome        1     0
# 4           4         Independant    Independant       sofia        1     0
# ..        ...                 ...            ...         ...      ...   ...
# 994       994            Yin Yang       Ardisson  copenhagen        0     0
# 995       995  Chillton Worldwide  Quadrupletree  copenhagen        0     0
# 996       996        Accar Hotels        Navatel      vienna        0     0
# 997       997  Chillton Worldwide     Tripletree      madrid        0     0
# 998       998            Yin Yang    Royal Lotus       paris        0     0
#
#      children_policy
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 994                0
# 995                0
# 996                0
# 997                0
# 998                0
#
# [999 rows x 7 columns]

# %%
Test = pd.read_csv('test_set.csv')
Test
# Out:
#       index  order_requests     city  date  language  mobile  avatar_id  \
# 0         0               1  vilnius    21  romanian       0          1
# 1         1               1  vilnius    21  romanian       0          1
# 2         2               1  vilnius    21  romanian       0          1
# 3         3               1  vilnius    21  romanian       0          1
# 4         4               1  vilnius    21  romanian       0          1
# ...     ...             ...      ...   ...       ...     ...        ...
# 6639   6639             843     rome     5     irish       0        794
# 6640   6640             844   vienna     1     irish       1        794
# 6641   6641             844   vienna     1     irish       1        794
# 6642   6642             844   vienna     1     irish       1        794
# 6643   6643             844   vienna     1     irish       1        794
#
#       hotel_id  stock
# 0          161     46
# 1          187     32
# 2          279     12
# 3          395     10
# 4          488     42
# ...        ...    ...
# 6639       987      1
# 6640        26      1
# 6641       263      0
# 6642       456      0
# 6643       699      0
#
# [6644 rows x 9 columns]

# %%
language = Test['language'].unique()
language
# Out:
# array(['romanian', 'swedish', 'maltese', 'belgian', 'luxembourgish',
#        'dutch', 'french', 'finnish', 'austrian', 'slovakian', 'hungarian',
#        'bulgarian', 'danish', 'greek', 'croatian', 'polish', 'german',
#        'spanish', 'estonian', 'lithuanian', 'cypriot', 'latvian', 'irish',
#        'italian', 'slovene', 'czech', 'portuguese'], dtype=object)

# %% [markdown]
# ## 1st strategy Requests

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)
user_id = '0965ef50-4892-4e22-923c-236be6b36411'

# %% [markdown]
# ### Requests 1

# %%
#Premier script 

# compteur = 0
# i = 0
# step = ['step7j_','step3j_']

# # MOBILE 0, départ 36e jour avec step 7 jours
# date = [36,16]
# mobile = [0,1]

# matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
# pricing_requests = []

# for h in range(2):
#     for i in range(2):
#         for j in range(np.shape(language)[0]):
#             for k in range(np.shape(city)[0]):
#                 a = random.randint(-2,2)
#                 name = "avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
#                 params = {
#                     "avatar_name": name ,
#                     "language": language[j],
#                     "city": city[k],
#                     "date": date[i] + a,
#                     "mobile": mobile[h],    
#                 }
#                 compteur +=1
#                 print(params)
    
#                 r1 = requests.post(path(f"avatars/{user_id}/{name}"))
#                 r1 = requests.get(path(f"pricing/{user_id}"), params=params)
#                 pricing_requests.append(
#                     pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
#                 )
#                 df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
#                 matrix_avatar = matrix_avatar.append(df_tmp)
                
                
# pricing_requests = pd.concat(pricing_requests)
# matrix_avatar_df = pd.DataFrame(matrix_avatar)
# matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)
# matrix_merge.to_csv('matrix_merge.csv')

# %%
# matrix_avatar = pd.DataFrame([],columns = ['id', 'name','order_request','city','date','mobile','language','stock','index'])

# for avatar in r.json():
#     df_tmp = pd.DataFrame([(avatar['id'],avatar['name'])], columns=['id', 'name'])
#     matrix_avatar = matrix_avatar.append(df_tmp)
# display(matrix_avatar)

# %%
requests1 = pd.read_csv('requests_1.csv')
display(requests1)
# Out:
#         Unnamed: 0  hotel_id  price  stock      city  date    language  \
# 0                0       663    149     84     paris    35    romanian
# 1                1       912    164     73     paris    35    romanian
# 2                2       640    152     70     paris    35    romanian
# 3                3       656    106     64     paris    35    romanian
# 4                4       792     82     76     paris    35    romanian
# ...            ...       ...    ...    ...       ...   ...         ...
# 100934      100934       491    167     24  valletta    15  portuguese
# 100935      100935       371    100      3  valletta    15  portuguese
# 100936      100936       334     82      5  valletta    15  portuguese
# 100937      100937       466    169     14  valletta    15  portuguese
# 100938      100938       389    121      2  valletta    15  portuguese
#
#         mobile  avatar_id                     name
# 0            0      38715    avatar_d35_step7j_0_0
# 1            0      38715    avatar_d35_step7j_0_0
# 2            0      38715    avatar_d35_step7j_0_0
# 3            0      38715    avatar_d35_step7j_0_0
# 4            0      38715    avatar_d35_step7j_0_0
# ...        ...        ...                      ...
# 100934       1      39686  avatar_d15_step3j_1_971
# 100935       1      39686  avatar_d15_step3j_1_971
# 100936       1      39686  avatar_d15_step3j_1_971
# 100937       1      39686  avatar_d15_step3j_1_971
# 100938       1      39686  avatar_d15_step3j_1_971
#
# [100939 rows x 10 columns]

# %%
new_matrix = pd.DataFrame(requests1['name'].unique(),columns = ['name'])      
visualisation = pd.merge(new_matrix,requests1, copy = False)
subset_requests = requests1[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
#visualisation.to_csv('nos_avatars.csv')
# Out:
#                            name  avatar_id  date    language  mobile  \
# 0         avatar_d35_step7j_0_0      38715    35    romanian       0
# 156       avatar_d36_step7j_0_1      38716    36    romanian       0
# 291       avatar_d37_step7j_0_2      38717    37    romanian       0
# 399       avatar_d34_step7j_0_3      38718    34    romanian       0
# 521       avatar_d38_step7j_0_4      38719    38    romanian       0
# ...                         ...        ...   ...         ...     ...
# 100525  avatar_d17_step3j_1_967      39682    17  portuguese       1
# 100576  avatar_d15_step3j_1_968      39683    15  portuguese       1
# 100663  avatar_d14_step3j_1_969      39684    14  portuguese       1
# 100769  avatar_d17_step3j_1_970      39685    17  portuguese       1
# 100893  avatar_d15_step3j_1_971      39686    15  portuguese       1
#
#               city
# 0            paris
# 156     copenhagen
# 291         madrid
# 399           rome
# 521          sofia
# ...            ...
# 100525       sofia
# 100576     vilnius
# 100663      vienna
# 100769   amsterdam
# 100893    valletta
#
# [972 rows x 6 columns]

# %%
date_plus_30j = visualisation[(visualisation["date"] >30)]
date_inf_20j = visualisation[(visualisation["date"] < 20)]

#Décaler les dates de 7 ou 3 jours
date_plus_30j["date"] = date_plus_30j["date"] - 7
date_inf_20j["date"] = date_inf_20j["date"] - 3

# %%
#Avatars avec leurs nouvelles dates de recherche
frames = [date_plus_30j, date_inf_20j]
result = pd.concat(frames)
display(result)
# Out:
#                            name  avatar_id  date    language  mobile  \
# 0         avatar_d35_step7j_0_0      38715    28    romanian       0
# 156       avatar_d36_step7j_0_1      38716    29    romanian       0
# 291       avatar_d37_step7j_0_2      38717    30    romanian       0
# 399       avatar_d34_step7j_0_3      38718    27    romanian       0
# 521       avatar_d38_step7j_0_4      38719    31    romanian       0
# ...                         ...        ...   ...         ...     ...
# 100525  avatar_d17_step3j_1_967      39682    14  portuguese       1
# 100576  avatar_d15_step3j_1_968      39683    12  portuguese       1
# 100663  avatar_d14_step3j_1_969      39684    11  portuguese       1
# 100769  avatar_d17_step3j_1_970      39685    14  portuguese       1
# 100893  avatar_d15_step3j_1_971      39686    12  portuguese       1
#
#               city
# 0            paris
# 156     copenhagen
# 291         madrid
# 399           rome
# 521          sofia
# ...            ...
# 100525       sofia
# 100576     vilnius
# 100663      vienna
# 100769   amsterdam
# 100893    valletta
#
# [972 rows x 6 columns]

# %%
# matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
# pricing_requests = []

# for h in range(2):
#     for i in range(2):
#         for j in range(np.shape(language)[0]):
#             for k in range(np.shape(city)[0]):
#                 a = random.randint(-2,2)
#                 name = "avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
#                 params = {
#                     "avatar_name": name ,
#                     "language": language[j],
#                     "city": city[k],
#                     "date": date[i] + a,
#                     "mobile": mobile[h],    
#                 }
#                 compteur +=1
#                 print(params)
    
#                 #r1 = requests.post(path(f"avatars/{user_id}/{name}"))
#                 #r1 = requests.get(path(f"pricing/{user_id}"), params=params)
#                 #pricing_requests.append(
#                 #    pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
#                 #)
#                 #df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
#                 #matrix_avatar = matrix_avatar.append(df_tmp)
                
                
# pricing_requests = pd.concat(pricing_requests)
# matrix_avatar_df = pd.DataFrame(matrix_avatar)
# matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)
# matrix_merge.to_csv('matrix_merge.csv')

# %%
requests_1 = pd.read_csv('requests_1.csv', index_col=0)
display(requests_1)
# Out:
#         hotel_id  price  stock      city  date    language  mobile  avatar_id  \
# 0            663    149     84     paris    35    romanian       0      38715
# 1            912    164     73     paris    35    romanian       0      38715
# 2            640    152     70     paris    35    romanian       0      38715
# 3            656    106     64     paris    35    romanian       0      38715
# 4            792     82     76     paris    35    romanian       0      38715
# ...          ...    ...    ...       ...   ...         ...     ...        ...
# 100934       491    167     24  valletta    15  portuguese       1      39686
# 100935       371    100      3  valletta    15  portuguese       1      39686
# 100936       334     82      5  valletta    15  portuguese       1      39686
# 100937       466    169     14  valletta    15  portuguese       1      39686
# 100938       389    121      2  valletta    15  portuguese       1      39686
#
#                            name
# 0         avatar_d35_step7j_0_0
# 1         avatar_d35_step7j_0_0
# 2         avatar_d35_step7j_0_0
# 3         avatar_d35_step7j_0_0
# 4         avatar_d35_step7j_0_0
# ...                         ...
# 100934  avatar_d15_step3j_1_971
# 100935  avatar_d15_step3j_1_971
# 100936  avatar_d15_step3j_1_971
# 100937  avatar_d15_step3j_1_971
# 100938  avatar_d15_step3j_1_971
#
# [100939 rows x 9 columns]

# %% [markdown]
# ### Requests 2

# %%
nos_avatars = pd.read_csv('nos_avatars.csv')
display(nos_avatars)

# %%
subset_requests = nos_avatars[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    35    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    36    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    37    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    34    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    38    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682    17  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683    15  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684    14  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685    17  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686    15  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
date_plus_30j = visualisation[(visualisation["date"] > 30)]
date_inf_20j = visualisation[(visualisation["date"] < 20)]

date_plus_30j["date"] = date_plus_30j["date"] - 7*3
date_inf_20j["date"] = date_inf_20j["date"] - 3*3

# display(date_plus_30j)
# display(date_inf_20j)
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
frames = [date_plus_30j, date_inf_20j]
result = pd.concat(frames)
display(result)

result['date'].unique()
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    14    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    15    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    16    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    13    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    17    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     8  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     6  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684     5  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     8  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     6  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
# matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
# pricing_requests = []

# compteur = 0
# for i in range(result.shape[0]):
# #for i in range(1):
#     params = {"avatar_name": result.iloc[i]['name'] ,
#                 "language": result.iloc[i]['language'],
#                 "city": result.iloc[i]['city'],
#                 "date": result.iloc[i]['date'],
#                 "mobile": result.iloc[i]['mobile'],    
#                 }
#     #print(params)
#     compteur += 1

#     #avatar_id = result.iloc[i]['avatar_id']
#     r1 = requests.get(path(f"pricing/{user_id}"), params=params)
#     pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
#     df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],result.iloc[i]['name'])], columns=['avatar_id', 'name'])
#     matrix_avatar = matrix_avatar.append(df_tmp)
    
# print(compteur)

# pricing_requests = pd.concat(pricing_requests)
# matrix_avatar_df = pd.DataFrame(matrix_avatar)
# matrix_merge_3 = pd.merge(pricing_requests,matrix_avatar_df)
# matrix_merge_3.to_csv('matrix_merge_3.csv')
# display(matrix_merge_3)

# %%
requests_2 = pd.read_csv('requests_2.csv', index_col=0)
display(requests_2)
# Out:
#         hotel_id  price  stock      city  date    language  mobile  avatar_id  \
# 0            785    204     21     paris    21    romanian       0      38715
# 1            323    284     58     paris    21    romanian       0      38715
# 2            972    101      8     paris    21    romanian       0      38715
# 3            705    144     18     paris    21    romanian       0      38715
# 4            357    163     25     paris    21    romanian       0      38715
# ...          ...    ...    ...       ...   ...         ...     ...        ...
# 104709       325    102      0  valletta    12  portuguese       1      39686
# 104710        81    166     12  valletta    12  portuguese       1      39686
# 104711       466    169      9  valletta    12  portuguese       1      39686
# 104712       719    213     15  valletta    12  portuguese       1      39686
# 104713       965    166     12  valletta    12  portuguese       1      39686
#
#                            name
# 0         avatar_d35_step7j_0_0
# 1         avatar_d35_step7j_0_0
# 2         avatar_d35_step7j_0_0
# 3         avatar_d35_step7j_0_0
# 4         avatar_d35_step7j_0_0
# ...                         ...
# 104709  avatar_d15_step3j_1_971
# 104710  avatar_d15_step3j_1_971
# 104711  avatar_d15_step3j_1_971
# 104712  avatar_d15_step3j_1_971
# 104713  avatar_d15_step3j_1_971
#
# [104714 rows x 9 columns]

# %% [markdown]
# ### Requests 3

# %%
requests_3 = pd.read_csv('requests_4.csv', index_col=0)
display(requests_3)
# Out:
#         hotel_id  price  stock      city  date    language  mobile  avatar_id  \
# 0            885    179     10     paris     7    romanian       0      38715
# 1            736    235      8     paris     7    romanian       0      38715
# 2            946    339      5     paris     7    romanian       0      38715
# 3             41    142      6     paris     7    romanian       0      38715
# 4            257    197      0     paris     7    romanian       0      38715
# ...          ...    ...    ...       ...   ...         ...     ...        ...
# 102889       719    291      2  valletta     3  portuguese       1      39686
# 102890       244    412      3  valletta     3  portuguese       1      39686
# 102891       965    171      3  valletta     3  portuguese       1      39686
# 102892       504    199      4  valletta     3  portuguese       1      39686
# 102893       746    169      5  valletta     3  portuguese       1      39686
#
#                            name
# 0         avatar_d35_step7j_0_0
# 1         avatar_d35_step7j_0_0
# 2         avatar_d35_step7j_0_0
# 3         avatar_d35_step7j_0_0
# 4         avatar_d35_step7j_0_0
# ...                         ...
# 102889  avatar_d15_step3j_1_971
# 102890  avatar_d15_step3j_1_971
# 102891  avatar_d15_step3j_1_971
# 102892  avatar_d15_step3j_1_971
# 102893  avatar_d15_step3j_1_971
#
# [102894 rows x 9 columns]

# %%
nos_avatars = pd.read_csv('nos_avatars.csv')
display(nos_avatars)
# Out:
#      Unnamed: 0                     name  avatar_id  date    language  mobile  \
# 0             0    avatar_d35_step7j_0_0      38715    35    romanian       0
# 1           156    avatar_d36_step7j_0_1      38716    36    romanian       0
# 2           291    avatar_d37_step7j_0_2      38717    37    romanian       0
# 3           399    avatar_d34_step7j_0_3      38718    34    romanian       0
# 4           521    avatar_d38_step7j_0_4      38719    38    romanian       0
# ..          ...                      ...        ...   ...         ...     ...
# 967      100525  avatar_d17_step3j_1_967      39682    17  portuguese       1
# 968      100576  avatar_d15_step3j_1_968      39683    15  portuguese       1
# 969      100663  avatar_d14_step3j_1_969      39684    14  portuguese       1
# 970      100769  avatar_d17_step3j_1_970      39685    17  portuguese       1
# 971      100893  avatar_d15_step3j_1_971      39686    15  portuguese       1
#
#            city
# 0         paris
# 1    copenhagen
# 2        madrid
# 3          rome
# 4         sofia
# ..          ...
# 967       sofia
# 968     vilnius
# 969      vienna
# 970   amsterdam
# 971    valletta
#
# [972 rows x 7 columns]

# %%
subset_requests = nos_avatars[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715    35    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716    36    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717    37    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    34    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719    38    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682    17  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683    15  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684    14  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685    17  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686    15  portuguese       1    valletta
#
# [972 rows x 6 columns]

# %%
date_plus_30j = visualisation[(visualisation["date"] > 30)]
date_inf_20j = visualisation[(visualisation["date"] < 20)]

date_plus_30j["date"] = date_plus_30j["date"] - 7*5
date_inf_20j["date"] = date_inf_20j["date"] - 3*5

# display(date_plus_30j)
# display(date_inf_20j)
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
display(date_plus_30j)
display(date_inf_20j)
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715     0    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716     1    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717     2    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    -1    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719     3    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 724  avatar_d38_step7j_1_724      39439     3  portuguese       1       sofia
# 725  avatar_d37_step7j_1_725      39440     2  portuguese       1     vilnius
# 726  avatar_d34_step7j_1_726      39441    -1  portuguese       1      vienna
# 727  avatar_d35_step7j_1_727      39442     0  portuguese       1   amsterdam
# 728  avatar_d37_step7j_1_728      39443     2  portuguese       1    valletta
#
# [486 rows x 6 columns]
#                         name  avatar_id  date    language  mobile        city
# 243  avatar_d15_step3j_0_243      38958     0    romanian       0       paris
# 244  avatar_d16_step3j_0_244      38959     1    romanian       0  copenhagen
# 245  avatar_d17_step3j_0_245      38960     2    romanian       0      madrid
# 246  avatar_d18_step3j_0_246      38961     3    romanian       0        rome
# 247  avatar_d18_step3j_0_247      38962     3    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     2  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     0  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684    -1  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     2  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     0  portuguese       1    valletta
#
# [486 rows x 6 columns]

# %%
frames = [date_plus_30j, date_inf_20j]
result = pd.concat(frames)
display(result)

result['date'].unique()
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715     0    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716     1    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717     2    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718    -1    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719     3    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     2  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     0  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684    -1  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     2  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     0  portuguese       1    valletta
#
# [972 rows x 6 columns]
# array([ 0,  1,  2, -1,  3], dtype=int64)

# %%
for i in range(result.shape[0]):
    if result.date[i] == -1:
        result.date[i] = 0
# Out:
# C:\Users\elise\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
display(result)
result.date.unique()
# Out:
#                         name  avatar_id  date    language  mobile        city
# 0      avatar_d35_step7j_0_0      38715     0    romanian       0       paris
# 1      avatar_d36_step7j_0_1      38716     1    romanian       0  copenhagen
# 2      avatar_d37_step7j_0_2      38717     2    romanian       0      madrid
# 3      avatar_d34_step7j_0_3      38718     0    romanian       0        rome
# 4      avatar_d38_step7j_0_4      38719     3    romanian       0       sofia
# ..                       ...        ...   ...         ...     ...         ...
# 967  avatar_d17_step3j_1_967      39682     2  portuguese       1       sofia
# 968  avatar_d15_step3j_1_968      39683     0  portuguese       1     vilnius
# 969  avatar_d14_step3j_1_969      39684     0  portuguese       1      vienna
# 970  avatar_d17_step3j_1_970      39685     2  portuguese       1   amsterdam
# 971  avatar_d15_step3j_1_971      39686     0  portuguese       1    valletta
#
# [972 rows x 6 columns]
# array([0, 1, 2, 3], dtype=int64)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

compteur = 0
for i in range(result.shape[0]):
# for i in range(1):
    params = {"avatar_name": result.iloc[i]['name'] ,
                "language": result.iloc[i]['language'],
                "city": result.iloc[i]['city'],
                "date": result.iloc[i]['date'],
                "mobile": result.iloc[i]['mobile'],    
                }
    print(params)
    compteur += 1

#     avatar_id = result.iloc[i]['avatar_id']
    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],result.iloc[i]['name'])], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    
print(compteur)

pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_merge_5 = pd.merge(pricing_requests,matrix_avatar_df)
matrix_merge_5.to_csv('requests_5.csv')
display(matrix_merge_5)
# Out:
# {'avatar_name': 'avatar_d35_step7j_0_0', 'language': 'romanian', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_1', 'language': 'romanian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_2', 'language': 'romanian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_3', 'language': 'romanian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_4', 'language': 'romanian', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_5', 'language': 'romanian', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_6', 'language': 'romanian', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_7', 'language': 'romanian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_8', 'language': 'romanian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_9', 'language': 'swedish', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_10', 'language': 'swedish', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_11', 'language': 'swedish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_12', 'language': 'swedish', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_13', 'language': 'swedish', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_14', 'language': 'swedish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_15', 'language': 'swedish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_16', 'language': 'swedish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_17', 'language': 'swedish', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_18', 'language': 'maltese', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_19', 'language': 'maltese', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_20', 'language': 'maltese', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_21', 'language': 'maltese', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_22', 'language': 'maltese', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_23', 'language': 'maltese', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_24', 'language': 'maltese', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_25', 'language': 'maltese', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_26', 'language': 'maltese', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_27', 'language': 'belgian', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_28', 'language': 'belgian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_29', 'language': 'belgian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_30', 'language': 'belgian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_31', 'language': 'belgian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_32', 'language': 'belgian', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_33', 'language': 'belgian', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_34', 'language': 'belgian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_35', 'language': 'belgian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_36', 'language': 'luxembourgish', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_37', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_38', 'language': 'luxembourgish', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_39', 'language': 'luxembourgish', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_40', 'language': 'luxembourgish', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_41', 'language': 'luxembourgish', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_42', 'language': 'luxembourgish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_43', 'language': 'luxembourgish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_44', 'language': 'luxembourgish', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_45', 'language': 'dutch', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_46', 'language': 'dutch', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_47', 'language': 'dutch', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_48', 'language': 'dutch', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_49', 'language': 'dutch', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_50', 'language': 'dutch', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_51', 'language': 'dutch', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_52', 'language': 'dutch', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_53', 'language': 'dutch', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_54', 'language': 'french', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_55', 'language': 'french', 'city': 'copenhagen', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_56', 'language': 'french', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_57', 'language': 'french', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_58', 'language': 'french', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_59', 'language': 'french', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_60', 'language': 'french', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_61', 'language': 'french', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_62', 'language': 'french', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_63', 'language': 'finnish', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_64', 'language': 'finnish', 'city': 'copenhagen', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_65', 'language': 'finnish', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_66', 'language': 'finnish', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_67', 'language': 'finnish', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_68', 'language': 'finnish', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_69', 'language': 'finnish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_70', 'language': 'finnish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_71', 'language': 'finnish', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_72', 'language': 'austrian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_73', 'language': 'austrian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_74', 'language': 'austrian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_75', 'language': 'austrian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_76', 'language': 'austrian', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_77', 'language': 'austrian', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_78', 'language': 'austrian', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_79', 'language': 'austrian', 'city': 'amsterdam', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_80', 'language': 'austrian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_81', 'language': 'slovakian', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_82', 'language': 'slovakian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_83', 'language': 'slovakian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_84', 'language': 'slovakian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_85', 'language': 'slovakian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_86', 'language': 'slovakian', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_87', 'language': 'slovakian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_88', 'language': 'slovakian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_89', 'language': 'slovakian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_90', 'language': 'hungarian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_91', 'language': 'hungarian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_92', 'language': 'hungarian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_93', 'language': 'hungarian', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_94', 'language': 'hungarian', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_95', 'language': 'hungarian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_96', 'language': 'hungarian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_97', 'language': 'hungarian', 'city': 'amsterdam', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_98', 'language': 'hungarian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_99', 'language': 'bulgarian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_100', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_101', 'language': 'bulgarian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_102', 'language': 'bulgarian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_103', 'language': 'bulgarian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_104', 'language': 'bulgarian', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_105', 'language': 'bulgarian', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_106', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_107', 'language': 'bulgarian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_108', 'language': 'danish', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_109', 'language': 'danish', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_110', 'language': 'danish', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_111', 'language': 'danish', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_112', 'language': 'danish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_113', 'language': 'danish', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_114', 'language': 'danish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_115', 'language': 'danish', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_116', 'language': 'danish', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_117', 'language': 'greek', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_118', 'language': 'greek', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_119', 'language': 'greek', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_120', 'language': 'greek', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_121', 'language': 'greek', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_122', 'language': 'greek', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_123', 'language': 'greek', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_124', 'language': 'greek', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_125', 'language': 'greek', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_126', 'language': 'croatian', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_127', 'language': 'croatian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_128', 'language': 'croatian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_129', 'language': 'croatian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_130', 'language': 'croatian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_131', 'language': 'croatian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_132', 'language': 'croatian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_133', 'language': 'croatian', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_134', 'language': 'croatian', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_135', 'language': 'polish', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_136', 'language': 'polish', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_137', 'language': 'polish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_138', 'language': 'polish', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_139', 'language': 'polish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_140', 'language': 'polish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_141', 'language': 'polish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_142', 'language': 'polish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_143', 'language': 'polish', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_144', 'language': 'german', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_145', 'language': 'german', 'city': 'copenhagen', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_146', 'language': 'german', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_147', 'language': 'german', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_148', 'language': 'german', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_149', 'language': 'german', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_150', 'language': 'german', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_151', 'language': 'german', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_152', 'language': 'german', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_153', 'language': 'spanish', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_154', 'language': 'spanish', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_155', 'language': 'spanish', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_156', 'language': 'spanish', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_157', 'language': 'spanish', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_158', 'language': 'spanish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_159', 'language': 'spanish', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_160', 'language': 'spanish', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_161', 'language': 'spanish', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_162', 'language': 'estonian', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_163', 'language': 'estonian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_164', 'language': 'estonian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_165', 'language': 'estonian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_166', 'language': 'estonian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_167', 'language': 'estonian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_168', 'language': 'estonian', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_169', 'language': 'estonian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_170', 'language': 'estonian', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_171', 'language': 'lithuanian', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_172', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_173', 'language': 'lithuanian', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_174', 'language': 'lithuanian', 'city': 'rome', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_175', 'language': 'lithuanian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_176', 'language': 'lithuanian', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_177', 'language': 'lithuanian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_178', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_179', 'language': 'lithuanian', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_180', 'language': 'cypriot', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_181', 'language': 'cypriot', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_182', 'language': 'cypriot', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_183', 'language': 'cypriot', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_184', 'language': 'cypriot', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_185', 'language': 'cypriot', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_186', 'language': 'cypriot', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_187', 'language': 'cypriot', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_188', 'language': 'cypriot', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_189', 'language': 'latvian', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_190', 'language': 'latvian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_191', 'language': 'latvian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_192', 'language': 'latvian', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_193', 'language': 'latvian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_194', 'language': 'latvian', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_195', 'language': 'latvian', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_196', 'language': 'latvian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_197', 'language': 'latvian', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_198', 'language': 'irish', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_199', 'language': 'irish', 'city': 'copenhagen', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_200', 'language': 'irish', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_201', 'language': 'irish', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_202', 'language': 'irish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_203', 'language': 'irish', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_204', 'language': 'irish', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_205', 'language': 'irish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_206', 'language': 'irish', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_207', 'language': 'italian', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_208', 'language': 'italian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_209', 'language': 'italian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_210', 'language': 'italian', 'city': 'rome', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_211', 'language': 'italian', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_212', 'language': 'italian', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_213', 'language': 'italian', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_214', 'language': 'italian', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_215', 'language': 'italian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_216', 'language': 'slovene', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_217', 'language': 'slovene', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_218', 'language': 'slovene', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_219', 'language': 'slovene', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_220', 'language': 'slovene', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_221', 'language': 'slovene', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_222', 'language': 'slovene', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_223', 'language': 'slovene', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_224', 'language': 'slovene', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_225', 'language': 'czech', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_226', 'language': 'czech', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_227', 'language': 'czech', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_228', 'language': 'czech', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_229', 'language': 'czech', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_230', 'language': 'czech', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_231', 'language': 'czech', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_232', 'language': 'czech', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_233', 'language': 'czech', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d37_step7j_0_234', 'language': 'portuguese', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_235', 'language': 'portuguese', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_236', 'language': 'portuguese', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_237', 'language': 'portuguese', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d35_step7j_0_238', 'language': 'portuguese', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d34_step7j_0_239', 'language': 'portuguese', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_240', 'language': 'portuguese', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_0_241', 'language': 'portuguese', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d38_step7j_0_242', 'language': 'portuguese', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d36_step7j_1_486', 'language': 'romanian', 'city': 'paris', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_487', 'language': 'romanian', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_488', 'language': 'romanian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_489', 'language': 'romanian', 'city': 'rome', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_490', 'language': 'romanian', 'city': 'sofia', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_491', 'language': 'romanian', 'city': 'vilnius', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_492', 'language': 'romanian', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_493', 'language': 'romanian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_494', 'language': 'romanian', 'city': 'valletta', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_495', 'language': 'swedish', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_496', 'language': 'swedish', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_497', 'language': 'swedish', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_498', 'language': 'swedish', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_499', 'language': 'swedish', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_500', 'language': 'swedish', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_501', 'language': 'swedish', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_502', 'language': 'swedish', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_503', 'language': 'swedish', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_504', 'language': 'maltese', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_505', 'language': 'maltese', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_506', 'language': 'maltese', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_507', 'language': 'maltese', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_508', 'language': 'maltese', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_509', 'language': 'maltese', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_510', 'language': 'maltese', 'city': 'vienna', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_511', 'language': 'maltese', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_512', 'language': 'maltese', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_513', 'language': 'belgian', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_514', 'language': 'belgian', 'city': 'copenhagen', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_515', 'language': 'belgian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_516', 'language': 'belgian', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_517', 'language': 'belgian', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_518', 'language': 'belgian', 'city': 'vilnius', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_519', 'language': 'belgian', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_520', 'language': 'belgian', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_521', 'language': 'belgian', 'city': 'valletta', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_522', 'language': 'luxembourgish', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_523', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_524', 'language': 'luxembourgish', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_525', 'language': 'luxembourgish', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_526', 'language': 'luxembourgish', 'city': 'sofia', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_527', 'language': 'luxembourgish', 'city': 'vilnius', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_528', 'language': 'luxembourgish', 'city': 'vienna', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_529', 'language': 'luxembourgish', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_530', 'language': 'luxembourgish', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_531', 'language': 'dutch', 'city': 'paris', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_532', 'language': 'dutch', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_533', 'language': 'dutch', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_534', 'language': 'dutch', 'city': 'rome', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_535', 'language': 'dutch', 'city': 'sofia', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_536', 'language': 'dutch', 'city': 'vilnius', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_537', 'language': 'dutch', 'city': 'vienna', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_538', 'language': 'dutch', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_539', 'language': 'dutch', 'city': 'valletta', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_540', 'language': 'french', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_541', 'language': 'french', 'city': 'copenhagen', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_542', 'language': 'french', 'city': 'madrid', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_543', 'language': 'french', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_544', 'language': 'french', 'city': 'sofia', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_545', 'language': 'french', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_546', 'language': 'french', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_547', 'language': 'french', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_548', 'language': 'french', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_549', 'language': 'finnish', 'city': 'paris', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_550', 'language': 'finnish', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_551', 'language': 'finnish', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_552', 'language': 'finnish', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_553', 'language': 'finnish', 'city': 'sofia', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_554', 'language': 'finnish', 'city': 'vilnius', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_555', 'language': 'finnish', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_556', 'language': 'finnish', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_557', 'language': 'finnish', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_558', 'language': 'austrian', 'city': 'paris', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_559', 'language': 'austrian', 'city': 'copenhagen', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_560', 'language': 'austrian', 'city': 'madrid', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_561', 'language': 'austrian', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_562', 'language': 'austrian', 'city': 'sofia', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_563', 'language': 'austrian', 'city': 'vilnius', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_564', 'language': 'austrian', 'city': 'vienna', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_565', 'language': 'austrian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_566', 'language': 'austrian', 'city': 'valletta', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_567', 'language': 'slovakian', 'city': 'paris', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_568', 'language': 'slovakian', 'city': 'copenhagen', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_569', 'language': 'slovakian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_570', 'language': 'slovakian', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_571', 'language': 'slovakian', 'city': 'sofia', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_572', 'language': 'slovakian', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_573', 'language': 'slovakian', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_574', 'language': 'slovakian', 'city': 'amsterdam', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_575', 'language': 'slovakian', 'city': 'valletta', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_576', 'language': 'hungarian', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_577', 'language': 'hungarian', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_578', 'language': 'hungarian', 'city': 'madrid', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_579', 'language': 'hungarian', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_580', 'language': 'hungarian', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_581', 'language': 'hungarian', 'city': 'vilnius', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_582', 'language': 'hungarian', 'city': 'vienna', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_583', 'language': 'hungarian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_584', 'language': 'hungarian', 'city': 'valletta', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_585', 'language': 'bulgarian', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_586', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_587', 'language': 'bulgarian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_588', 'language': 'bulgarian', 'city': 'rome', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_589', 'language': 'bulgarian', 'city': 'sofia', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_590', 'language': 'bulgarian', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_591', 'language': 'bulgarian', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_592', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_593', 'language': 'bulgarian', 'city': 'valletta', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_594', 'language': 'danish', 'city': 'paris', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_595', 'language': 'danish', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_596', 'language': 'danish', 'city': 'madrid', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_597', 'language': 'danish', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_598', 'language': 'danish', 'city': 'sofia', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_599', 'language': 'danish', 'city': 'vilnius', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_600', 'language': 'danish', 'city': 'vienna', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_601', 'language': 'danish', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_602', 'language': 'danish', 'city': 'valletta', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_603', 'language': 'greek', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_604', 'language': 'greek', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_605', 'language': 'greek', 'city': 'madrid', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_606', 'language': 'greek', 'city': 'rome', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_607', 'language': 'greek', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_608', 'language': 'greek', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_609', 'language': 'greek', 'city': 'vienna', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_610', 'language': 'greek', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_611', 'language': 'greek', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_612', 'language': 'croatian', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_613', 'language': 'croatian', 'city': 'copenhagen', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_614', 'language': 'croatian', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_615', 'language': 'croatian', 'city': 'rome', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_616', 'language': 'croatian', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_617', 'language': 'croatian', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_618', 'language': 'croatian', 'city': 'vienna', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_619', 'language': 'croatian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_620', 'language': 'croatian', 'city': 'valletta', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_621', 'language': 'polish', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_622', 'language': 'polish', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_623', 'language': 'polish', 'city': 'madrid', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_624', 'language': 'polish', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_625', 'language': 'polish', 'city': 'sofia', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_626', 'language': 'polish', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_627', 'language': 'polish', 'city': 'vienna', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_628', 'language': 'polish', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_629', 'language': 'polish', 'city': 'valletta', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_630', 'language': 'german', 'city': 'paris', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_631', 'language': 'german', 'city': 'copenhagen', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_632', 'language': 'german', 'city': 'madrid', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_633', 'language': 'german', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_634', 'language': 'german', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_635', 'language': 'german', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_636', 'language': 'german', 'city': 'vienna', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_637', 'language': 'german', 'city': 'amsterdam', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_638', 'language': 'german', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_639', 'language': 'spanish', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_640', 'language': 'spanish', 'city': 'copenhagen', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_641', 'language': 'spanish', 'city': 'madrid', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_642', 'language': 'spanish', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_643', 'language': 'spanish', 'city': 'sofia', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_644', 'language': 'spanish', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_645', 'language': 'spanish', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_646', 'language': 'spanish', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_647', 'language': 'spanish', 'city': 'valletta', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_648', 'language': 'estonian', 'city': 'paris', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_649', 'language': 'estonian', 'city': 'copenhagen', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_650', 'language': 'estonian', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_651', 'language': 'estonian', 'city': 'rome', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_652', 'language': 'estonian', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_653', 'language': 'estonian', 'city': 'vilnius', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_654', 'language': 'estonian', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_655', 'language': 'estonian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_656', 'language': 'estonian', 'city': 'valletta', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_657', 'language': 'lithuanian', 'city': 'paris', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_658', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_659', 'language': 'lithuanian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_660', 'language': 'lithuanian', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_661', 'language': 'lithuanian', 'city': 'sofia', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_662', 'language': 'lithuanian', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d34_step7j_1_663', 'language': 'lithuanian', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_664', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_665', 'language': 'lithuanian', 'city': 'valletta', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_666', 'language': 'cypriot', 'city': 'paris', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_667', 'language': 'cypriot', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_668', 'language': 'cypriot', 'city': 'madrid', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_669', 'language': 'cypriot', 'city': 'rome', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_670', 'language': 'cypriot', 'city': 'sofia', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_671', 'language': 'cypriot', 'city': 'vilnius', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_672', 'language': 'cypriot', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_673', 'language': 'cypriot', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d37_step7j_1_674', 'language': 'cypriot', 'city': 'valletta', 'date': 2, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_675', 'language': 'latvian', 'city': 'paris', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d36_step7j_1_676', 'language': 'latvian', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# {'avatar_name': 'avatar_d38_step7j_1_677', 'language': 'latvian', 'city': 'madrid', 'date': 3, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_678', 'language': 'latvian', 'city': 'rome', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_679', 'language': 'latvian', 'city': 'sofia', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_680', 'language': 'latvian', 'city': 'vilnius', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_681', 'language': 'latvian', 'city': 'vienna', 'date': 0, 'mobile': 1}
# {'avatar_name': 'avatar_d35_step7j_1_682', 'language': 'latvian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# ...
# {'avatar_name': 'avatar_d17_step3j_0_313', 'language': 'finnish', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_314', 'language': 'finnish', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_315', 'language': 'austrian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_316', 'language': 'austrian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_317', 'language': 'austrian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_318', 'language': 'austrian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_319', 'language': 'austrian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_320', 'language': 'austrian', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_321', 'language': 'austrian', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_322', 'language': 'austrian', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_323', 'language': 'austrian', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_324', 'language': 'slovakian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_325', 'language': 'slovakian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_326', 'language': 'slovakian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_327', 'language': 'slovakian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_328', 'language': 'slovakian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_329', 'language': 'slovakian', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_330', 'language': 'slovakian', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_331', 'language': 'slovakian', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_332', 'language': 'slovakian', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_333', 'language': 'hungarian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_334', 'language': 'hungarian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_335', 'language': 'hungarian', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_336', 'language': 'hungarian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_337', 'language': 'hungarian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_338', 'language': 'hungarian', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_339', 'language': 'hungarian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_340', 'language': 'hungarian', 'city': 'amsterdam', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_341', 'language': 'hungarian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_342', 'language': 'bulgarian', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_343', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_344', 'language': 'bulgarian', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_345', 'language': 'bulgarian', 'city': 'rome', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_346', 'language': 'bulgarian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_347', 'language': 'bulgarian', 'city': 'vilnius', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_348', 'language': 'bulgarian', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_349', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_350', 'language': 'bulgarian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_351', 'language': 'danish', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_352', 'language': 'danish', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_353', 'language': 'danish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_354', 'language': 'danish', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_355', 'language': 'danish', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_356', 'language': 'danish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_357', 'language': 'danish', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_358', 'language': 'danish', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_359', 'language': 'danish', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_360', 'language': 'greek', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_361', 'language': 'greek', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_362', 'language': 'greek', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_363', 'language': 'greek', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_364', 'language': 'greek', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_365', 'language': 'greek', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_366', 'language': 'greek', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_367', 'language': 'greek', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_368', 'language': 'greek', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_369', 'language': 'croatian', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_370', 'language': 'croatian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_371', 'language': 'croatian', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_372', 'language': 'croatian', 'city': 'rome', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_373', 'language': 'croatian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_374', 'language': 'croatian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_375', 'language': 'croatian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_376', 'language': 'croatian', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_377', 'language': 'croatian', 'city': 'valletta', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_378', 'language': 'polish', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_379', 'language': 'polish', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_380', 'language': 'polish', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_381', 'language': 'polish', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_382', 'language': 'polish', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_383', 'language': 'polish', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_384', 'language': 'polish', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_385', 'language': 'polish', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_386', 'language': 'polish', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_387', 'language': 'german', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_388', 'language': 'german', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_389', 'language': 'german', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_390', 'language': 'german', 'city': 'rome', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_391', 'language': 'german', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_392', 'language': 'german', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_393', 'language': 'german', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_394', 'language': 'german', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_395', 'language': 'german', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_396', 'language': 'spanish', 'city': 'paris', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_397', 'language': 'spanish', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_398', 'language': 'spanish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_399', 'language': 'spanish', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_400', 'language': 'spanish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_401', 'language': 'spanish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_402', 'language': 'spanish', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_403', 'language': 'spanish', 'city': 'amsterdam', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_404', 'language': 'spanish', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_405', 'language': 'estonian', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_406', 'language': 'estonian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_407', 'language': 'estonian', 'city': 'madrid', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_408', 'language': 'estonian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_409', 'language': 'estonian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_410', 'language': 'estonian', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_411', 'language': 'estonian', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_412', 'language': 'estonian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_413', 'language': 'estonian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_414', 'language': 'lithuanian', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_415', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_416', 'language': 'lithuanian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_417', 'language': 'lithuanian', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_418', 'language': 'lithuanian', 'city': 'sofia', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_419', 'language': 'lithuanian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_420', 'language': 'lithuanian', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_421', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_422', 'language': 'lithuanian', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_423', 'language': 'cypriot', 'city': 'paris', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_424', 'language': 'cypriot', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_425', 'language': 'cypriot', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_426', 'language': 'cypriot', 'city': 'rome', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_427', 'language': 'cypriot', 'city': 'sofia', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_428', 'language': 'cypriot', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_429', 'language': 'cypriot', 'city': 'vienna', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_430', 'language': 'cypriot', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_431', 'language': 'cypriot', 'city': 'valletta', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_432', 'language': 'latvian', 'city': 'paris', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_433', 'language': 'latvian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_434', 'language': 'latvian', 'city': 'madrid', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_435', 'language': 'latvian', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_436', 'language': 'latvian', 'city': 'sofia', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_437', 'language': 'latvian', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_438', 'language': 'latvian', 'city': 'vienna', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_439', 'language': 'latvian', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_440', 'language': 'latvian', 'city': 'valletta', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_441', 'language': 'irish', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_442', 'language': 'irish', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_443', 'language': 'irish', 'city': 'madrid', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_444', 'language': 'irish', 'city': 'rome', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_445', 'language': 'irish', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_446', 'language': 'irish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_447', 'language': 'irish', 'city': 'vienna', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_448', 'language': 'irish', 'city': 'amsterdam', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_449', 'language': 'irish', 'city': 'valletta', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_450', 'language': 'italian', 'city': 'paris', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d16_step3j_0_451', 'language': 'italian', 'city': 'copenhagen', 'date': 1, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_452', 'language': 'italian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_453', 'language': 'italian', 'city': 'rome', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d14_step3j_0_454', 'language': 'italian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_455', 'language': 'italian', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d18_step3j_0_456', 'language': 'italian', 'city': 'vienna', 'date': 3, 'mobile': 0}
# {'avatar_name': 'avatar_d15_step3j_0_457', 'language': 'italian', 'city': 'amsterdam', 'date': 0, 'mobile': 0}
# {'avatar_name': 'avatar_d17_step3j_0_458', 'language': 'italian', 'city': 'valletta', 'date': 2, 'mobile': 0}

# %%
requests_5 = pd.read_csv('requests_5.csv', index_col=0)
display(requests_5)

# %% [markdown]
# ## 2nd strategy Requests

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)
user_id = '0965ef50-4892-4e22-923c-236be6b36411'

# %%
language = Test['language'].unique()
language
# Out:
# array(['romanian', 'swedish', 'maltese', 'belgian', 'luxembourgish',
#        'dutch', 'french', 'finnish', 'austrian', 'slovakian', 'hungarian',
#        'bulgarian', 'danish', 'greek', 'croatian', 'polish', 'german',
#        'spanish', 'estonian', 'lithuanian', 'cypriot', 'latvian', 'irish',
#        'italian', 'slovene', 'czech', 'portuguese'], dtype=object)

# %%
city = Test['city'].unique()
city
# Out:
# array(['vilnius', 'paris', 'valletta', 'madrid', 'amsterdam',
#        'copenhagen', 'rome', 'sofia', 'vienna'], dtype=object)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []
compteur = 0


for j in range(np.shape(language)[0]):
#for j in range(1) :
    a = random.randint(-2,2)
    b = random.randint(0,1)
    name = "avatar_d_"+str(language[j])+"_plusieurs_villes"
    params = {
            "avatar_name": name ,
            "language": language[j],
            "city": city[1],
            "date": 10 + a,
            "mobile": b,    
    }
    compteur +=1
    print(params)
    
#     r1 = requests.post(path(f"avatars/{user_id}/{name}"))
#     r1 = requests.get(path(f"pricing/{user_id}"), params=params)
#     pricing_requests.append(
#         pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
#     )
#     df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
#     matrix_avatar = matrix_avatar.append(df_tmp)
    

    
print(compteur)

pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
sub_matrix_1 = pd.merge(pricing_requests,matrix_avatar_df)
# sub_matrix_1.to_csv('requests_5.csv')
# display(matrix_merge_5)
display(sub_matrix_1)
# Out:
# {'avatar_name': 'avatar_d_romanian_plusieurs_villes', 'language': 'romanian', 'city': 'paris', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_plusieurs_villes', 'language': 'swedish', 'city': 'paris', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_plusieurs_villes', 'language': 'maltese', 'city': 'paris', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_plusieurs_villes', 'language': 'belgian', 'city': 'paris', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_plusieurs_villes', 'language': 'luxembourgish', 'city': 'paris', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_plusieurs_villes', 'language': 'dutch', 'city': 'paris', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_plusieurs_villes', 'language': 'french', 'city': 'paris', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_plusieurs_villes', 'language': 'finnish', 'city': 'paris', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_plusieurs_villes', 'language': 'austrian', 'city': 'paris', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_plusieurs_villes', 'language': 'slovakian', 'city': 'paris', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_plusieurs_villes', 'language': 'hungarian', 'city': 'paris', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_plusieurs_villes', 'language': 'bulgarian', 'city': 'paris', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_plusieurs_villes', 'language': 'danish', 'city': 'paris', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_plusieurs_villes', 'language': 'greek', 'city': 'paris', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_plusieurs_villes', 'language': 'croatian', 'city': 'paris', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_plusieurs_villes', 'language': 'polish', 'city': 'paris', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_plusieurs_villes', 'language': 'german', 'city': 'paris', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_plusieurs_villes', 'language': 'spanish', 'city': 'paris', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_plusieurs_villes', 'language': 'estonian', 'city': 'paris', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_plusieurs_villes', 'language': 'lithuanian', 'city': 'paris', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_plusieurs_villes', 'language': 'cypriot', 'city': 'paris', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_plusieurs_villes', 'language': 'latvian', 'city': 'paris', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_plusieurs_villes', 'language': 'irish', 'city': 'paris', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_plusieurs_villes', 'language': 'italian', 'city': 'paris', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_plusieurs_villes', 'language': 'slovene', 'city': 'paris', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_plusieurs_villes', 'language': 'czech', 'city': 'paris', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_plusieurs_villes', 'language': 'portuguese', 'city': 'paris', 'date': 11, 'mobile': 1}
# 27
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\337829879.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#       hotel_id  price  stock   city  date    language  mobile avatar_id  \
# 0          248    250     10  paris    12    romanian       0    191007
# 1          825    187     13  paris    12    romanian       0    191007
# 2          199    228      0  paris    12    romanian       0    191007
# 3          903     89      0  paris    12    romanian       0    191007
# 4          602    115      4  paris    12    romanian       0    191007
# ...        ...    ...    ...    ...   ...         ...     ...       ...
# 4450       741    194     11  paris    11  portuguese       1    191033
# 4451       582    250     12  paris    11  portuguese       1    191033
# 4452       722    197     10  paris    11  portuguese       1    191033
# 4453       339    258     15  paris    11  portuguese       1    191033
# 4454       735    158      4  paris    11  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 4450  avatar_d_portuguese_plusieurs_villes
# 4451  avatar_d_portuguese_plusieurs_villes
# 4452  avatar_d_portuguese_plusieurs_villes
# 4453  avatar_d_portuguese_plusieurs_villes
# 4454  avatar_d_portuguese_plusieurs_villes
#
# [4455 rows x 9 columns]

# %%
new_matrix = pd.DataFrame(sub_matrix_1['name'].unique(),columns = ['name'])      
visualisation = pd.merge(new_matrix,sub_matrix_1, copy = False)
subset_requests = sub_matrix_1[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
print(visualisation.shape)
# Out:
#                                          name avatar_id  date       language  \
# 0          avatar_d_romanian_plusieurs_villes    191007    12       romanian
# 165         avatar_d_swedish_plusieurs_villes    191008    11        swedish
# 330         avatar_d_maltese_plusieurs_villes    191009     9        maltese
# 495         avatar_d_belgian_plusieurs_villes    191010    11        belgian
# 660   avatar_d_luxembourgish_plusieurs_villes    191011     9  luxembourgish
# 825           avatar_d_dutch_plusieurs_villes    191012     8          dutch
# 990          avatar_d_french_plusieurs_villes    191013    11         french
# 1155        avatar_d_finnish_plusieurs_villes    191014    10        finnish
# 1320       avatar_d_austrian_plusieurs_villes    191015    12       austrian
# 1485      avatar_d_slovakian_plusieurs_villes    191016    12      slovakian
# 1650      avatar_d_hungarian_plusieurs_villes    191017    10      hungarian
# 1815      avatar_d_bulgarian_plusieurs_villes    191018     9      bulgarian
# 1980         avatar_d_danish_plusieurs_villes    191019    12         danish
# 2145          avatar_d_greek_plusieurs_villes    191020     9          greek
# 2310       avatar_d_croatian_plusieurs_villes    191021     9       croatian
# 2475         avatar_d_polish_plusieurs_villes    191022     9         polish
# 2640         avatar_d_german_plusieurs_villes    191023    12         german
# 2805        avatar_d_spanish_plusieurs_villes    191024     9        spanish
# 2970       avatar_d_estonian_plusieurs_villes    191025    11       estonian
# 3135     avatar_d_lithuanian_plusieurs_villes    191026    11     lithuanian
# 3300        avatar_d_cypriot_plusieurs_villes    191027    11        cypriot
# 3465        avatar_d_latvian_plusieurs_villes    191028    12        latvian
# 3630          avatar_d_irish_plusieurs_villes    191029    12          irish
# 3795        avatar_d_italian_plusieurs_villes    191030    11        italian
# 3960        avatar_d_slovene_plusieurs_villes    191031    10        slovene
# 4125          avatar_d_czech_plusieurs_villes    191032     9          czech
# 4290     avatar_d_portuguese_plusieurs_villes    191033    11     portuguese
#
#       mobile   city
# 0          0  paris
# 165        0  paris
# 330        0  paris
# 495        1  paris
# 660        1  paris
# 825        0  paris
# 990        1  paris
# 1155       0  paris
# 1320       1  paris
# 1485       0  paris
# 1650       0  paris
# 1815       0  paris
# 1980       0  paris
# 2145       0  paris
# 2310       1  paris
# 2475       1  paris
# 2640       1  paris
# 2805       1  paris
# 2970       1  paris
# 3135       0  paris
# 3300       1  paris
# 3465       0  paris
# 3630       1  paris
# 3795       0  paris
# 3960       0  paris
# 4125       0  paris
# 4290       1  paris
# (27, 6)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

compteur = 0
for i in range(visualisation.shape[0]):
# for i in range(1):
    params = {"avatar_name": visualisation.iloc[i]['name'] ,
                "language": visualisation.iloc[i]['language'],
                "city": city[3],
                "date": 2,
                "mobile": visualisation.iloc[i]['mobile'],    
                }
    print(params)
    compteur += 1

    # avatar_id = visualisation.iloc[i]['avatar_id']
    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],visualisation.iloc[i]['name'])], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
sub_matrix_7_round_3 = pd.merge(pricing_requests,matrix_avatar_df)
# sub_matrix_1.to_csv('requests_5.csv')
# display(matrix_merge_5)
display(sub_matrix_7_round_3)
# Out:
# {'avatar_name': 'avatar_d_romanian_plusieurs_villes', 'language': 'romanian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_plusieurs_villes', 'language': 'swedish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_plusieurs_villes', 'language': 'maltese', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_plusieurs_villes', 'language': 'belgian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_plusieurs_villes', 'language': 'luxembourgish', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_plusieurs_villes', 'language': 'dutch', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_plusieurs_villes', 'language': 'french', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_plusieurs_villes', 'language': 'finnish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_plusieurs_villes', 'language': 'austrian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_plusieurs_villes', 'language': 'slovakian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_plusieurs_villes', 'language': 'hungarian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_plusieurs_villes', 'language': 'bulgarian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_plusieurs_villes', 'language': 'danish', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_plusieurs_villes', 'language': 'greek', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_plusieurs_villes', 'language': 'croatian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_plusieurs_villes', 'language': 'polish', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_plusieurs_villes', 'language': 'german', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_plusieurs_villes', 'language': 'spanish', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_plusieurs_villes', 'language': 'estonian', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_plusieurs_villes', 'language': 'lithuanian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_plusieurs_villes', 'language': 'cypriot', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_plusieurs_villes', 'language': 'latvian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_plusieurs_villes', 'language': 'irish', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_plusieurs_villes', 'language': 'italian', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_plusieurs_villes', 'language': 'slovene', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_plusieurs_villes', 'language': 'czech', 'city': 'madrid', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_plusieurs_villes', 'language': 'portuguese', 'city': 'madrid', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\3091397758.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#       hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0          982    240      1  madrid     2    romanian       0    191007
# 1          873    223      6  madrid     2    romanian       0    191007
# 2          729    348      2  madrid     2    romanian       0    191007
# 3          600     65      0  madrid     2    romanian       0    191007
# 4          252    259      1  madrid     2    romanian       0    191007
# ...        ...    ...    ...     ...   ...         ...     ...       ...
# 2884       904    112      0  madrid     2  portuguese       1    191033
# 2885       689     87      0  madrid     2  portuguese       1    191033
# 2886       164    133      2  madrid     2  portuguese       1    191033
# 2887       478    101      1  madrid     2  portuguese       1    191033
# 2888       185    146      0  madrid     2  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 2884  avatar_d_portuguese_plusieurs_villes
# 2885  avatar_d_portuguese_plusieurs_villes
# 2886  avatar_d_portuguese_plusieurs_villes
# 2887  avatar_d_portuguese_plusieurs_villes
# 2888  avatar_d_portuguese_plusieurs_villes
#
# [2889 rows x 9 columns]

# %%
display(sub_matrix_1)
display(sub_matrix_2)
display(sub_matrix_3)
display(sub_matrix_4)
display(sub_matrix_5_round_2)
display(sub_matrix_6_round_2)
display(sub_matrix_7_round_3)
# Out:
#       hotel_id  price  stock   city  date    language  mobile avatar_id  \
# 0          248    250     10  paris    12    romanian       0    191007
# 1          825    187     13  paris    12    romanian       0    191007
# 2          199    228      0  paris    12    romanian       0    191007
# 3          903     89      0  paris    12    romanian       0    191007
# 4          602    115      4  paris    12    romanian       0    191007
# ...        ...    ...    ...    ...   ...         ...     ...       ...
# 4450       741    194     11  paris    11  portuguese       1    191033
# 4451       582    250     12  paris    11  portuguese       1    191033
# 4452       722    197     10  paris    11  portuguese       1    191033
# 4453       339    258     15  paris    11  portuguese       1    191033
# 4454       735    158      4  paris    11  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 4450  avatar_d_portuguese_plusieurs_villes
# 4451  avatar_d_portuguese_plusieurs_villes
# 4452  avatar_d_portuguese_plusieurs_villes
# 4453  avatar_d_portuguese_plusieurs_villes
# 4454  avatar_d_portuguese_plusieurs_villes
#
# [4455 rows x 9 columns]
#       hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0          313     69      0  madrid    12    romanian       0    191007
# 1          186    129      9  madrid    12    romanian       0    191007
# 2          857    109     10  madrid    12    romanian       0    191007
# 3          822    187     16  madrid    12    romanian       0    191007
# 4          285     91      0  madrid    12    romanian       0    191007
# ...        ...    ...    ...     ...   ...         ...     ...       ...
# 3127       780    282     11  madrid    11  portuguese       1    191033
# 3128       175    107      4  madrid    11  portuguese       1    191033
# 3129       527    144      2  madrid    11  portuguese       1    191033
# 3130       102    267     17  madrid    11  portuguese       1    191033
# 3131       747    172     15  madrid    11  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 3127  avatar_d_portuguese_plusieurs_villes
# 3128  avatar_d_portuguese_plusieurs_villes
# 3129  avatar_d_portuguese_plusieurs_villes
# 3130  avatar_d_portuguese_plusieurs_villes
# 3131  avatar_d_portuguese_plusieurs_villes
#
# [3132 rows x 9 columns]
#       hotel_id  price  stock  city  date    language  mobile avatar_id  \
# 0          874    231     13  rome    12    romanian       0    191007
# 1          677    208     15  rome    12    romanian       0    191007
# 2          804    154      7  rome    12    romanian       0    191007
# 3          651    110     10  rome    12    romanian       0    191007
# 4          399    177     15  rome    12    romanian       0    191007
# ...        ...    ...    ...   ...   ...         ...     ...       ...
# 3451       206    178     20  rome    11  portuguese       1    191033
# 3452       180     75      0  rome    11  portuguese       1    191033
# 3453       328     73      0  rome    11  portuguese       1    191033
# 3454       156     74      0  rome    11  portuguese       1    191033
# 3455       816     85      6  rome    11  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 3451  avatar_d_portuguese_plusieurs_villes
# 3452  avatar_d_portuguese_plusieurs_villes
# 3453  avatar_d_portuguese_plusieurs_villes
# 3454  avatar_d_portuguese_plusieurs_villes
# 3455  avatar_d_portuguese_plusieurs_villes
#
# [3456 rows x 9 columns]
#       hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0          382    144     12  vienna    12    romanian       0    191007
# 1          372    121      9  vienna    12    romanian       0    191007
# 2          613    218     10  vienna    12    romanian       0    191007
# 3          846    288      8  vienna    12    romanian       0    191007
# 4          315    251     25  vienna    12    romanian       0    191007
# ...        ...    ...    ...     ...   ...         ...     ...       ...
# 2857       220     94      9  vienna    11  portuguese       1    191033
# 2858       801    245     10  vienna    11  portuguese       1    191033
# 2859       239    357     14  vienna    11  portuguese       1    191033
# 2860       438    116      0  vienna    11  portuguese       1    191033
# 2861       713    236      7  vienna    11  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 2857  avatar_d_portuguese_plusieurs_villes
# 2858  avatar_d_portuguese_plusieurs_villes
# 2859  avatar_d_portuguese_plusieurs_villes
# 2860  avatar_d_portuguese_plusieurs_villes
# 2861  avatar_d_portuguese_plusieurs_villes
#
# [2862 rows x 9 columns]
#       hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0          276     72      0  madrid     7    romanian       0    191007
# 1          721     71      0  madrid     7    romanian       0    191007
# 2          414     67      0  madrid     7    romanian       0    191007
# 3          411     96      0  madrid     7    romanian       0    191007
# 4          857    113      6  madrid     7    romanian       0    191007
# ...        ...    ...    ...     ...   ...         ...     ...       ...
# 2947       600     62      0  madrid     6  portuguese       1    191033
# 2948       388    124      0  madrid     6  portuguese       1    191033
# 2949       619    121      0  madrid     6  portuguese       1    191033
# 2950       414     64      0  madrid     6  portuguese       1    191033
# 2951        93    255      8  madrid     6  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 2947  avatar_d_portuguese_plusieurs_villes
# 2948  avatar_d_portuguese_plusieurs_villes
# 2949  avatar_d_portuguese_plusieurs_villes
# 2950  avatar_d_portuguese_plusieurs_villes
# 2951  avatar_d_portuguese_plusieurs_villes
#
# [2952 rows x 9 columns]
#       hotel_id  price  stock  city  date    language  mobile avatar_id  \
# 0          381    129      0  rome     7    romanian       0    191007
# 1          636     94      0  rome     7    romanian       0    191007
# 2          213     94      0  rome     7    romanian       0    191007
# 3          850    213      6  rome     7    romanian       0    191007
# 4          453    370      7  rome     7    romanian       0    191007
# ...        ...    ...    ...   ...   ...         ...     ...       ...
# 3291       537    197      8  rome     6  portuguese       1    191033
# 3292       345    139      0  rome     6  portuguese       1    191033
# 3293       486    198      8  rome     6  portuguese       1    191033
# 3294       668    119      0  rome     6  portuguese       1    191033
# 3295       386    106      0  rome     6  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 3291  avatar_d_portuguese_plusieurs_villes
# 3292  avatar_d_portuguese_plusieurs_villes
# 3293  avatar_d_portuguese_plusieurs_villes
# 3294  avatar_d_portuguese_plusieurs_villes
# 3295  avatar_d_portuguese_plusieurs_villes
#
# [3296 rows x 9 columns]
#       hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0          982    240      1  madrid     2    romanian       0    191007
# 1          873    223      6  madrid     2    romanian       0    191007
# 2          729    348      2  madrid     2    romanian       0    191007
# 3          600     65      0  madrid     2    romanian       0    191007
# 4          252    259      1  madrid     2    romanian       0    191007
# ...        ...    ...    ...     ...   ...         ...     ...       ...
# 2884       904    112      0  madrid     2  portuguese       1    191033
# 2885       689     87      0  madrid     2  portuguese       1    191033
# 2886       164    133      2  madrid     2  portuguese       1    191033
# 2887       478    101      1  madrid     2  portuguese       1    191033
# 2888       185    146      0  madrid     2  portuguese       1    191033
#
#                                       name
# 0       avatar_d_romanian_plusieurs_villes
# 1       avatar_d_romanian_plusieurs_villes
# 2       avatar_d_romanian_plusieurs_villes
# 3       avatar_d_romanian_plusieurs_villes
# 4       avatar_d_romanian_plusieurs_villes
# ...                                    ...
# 2884  avatar_d_portuguese_plusieurs_villes
# 2885  avatar_d_portuguese_plusieurs_villes
# 2886  avatar_d_portuguese_plusieurs_villes
# 2887  avatar_d_portuguese_plusieurs_villes
# 2888  avatar_d_portuguese_plusieurs_villes
#
# [2889 rows x 9 columns]

# %%
print("Paris",np.mean(sub_matrix_1.price))
print("Madrid",np.mean(sub_matrix_2.price))
print("Rome",np.mean(sub_matrix_3.price))
print("Vienne",np.mean(sub_matrix_4.price))
# Out:
# Paris 204.43254769921435
# Madrid 149.91890166028097
# Rome 160.71412037037038
# Vienne 164.82250174703006

# %%
print("Madrid",np.mean(sub_matrix_5_round_2.price))
print("Rome",np.mean(sub_matrix_6_round_2.price))
# Out:
# Madrid 157.62533875338752
# Rome 165.10709951456312

# %%
import seaborn as sns
sns.boxplot(sub_matrix_1.price)
# Out:
# <AxesSubplot:>

# %%
requets6_part_1= pd.concat([sub_matrix_1,sub_matrix_2,sub_matrix_3,sub_matrix_4,sub_matrix_5_round_2,sub_matrix_6_round_2,sub_matrix_7_round_3], ignore_index=True)

# %%
display(requets6_part_1)
requets6_part_1.to_csv('requests_6_part1.csv')
# Out:
#        hotel_id  price  stock    city  date    language  mobile avatar_id  \
# 0           248    250     10   paris    12    romanian       0    191007
# 1           825    187     13   paris    12    romanian       0    191007
# 2           199    228      0   paris    12    romanian       0    191007
# 3           903     89      0   paris    12    romanian       0    191007
# 4           602    115      4   paris    12    romanian       0    191007
# ...         ...    ...    ...     ...   ...         ...     ...       ...
# 23037       904    112      0  madrid     2  portuguese       1    191033
# 23038       689     87      0  madrid     2  portuguese       1    191033
# 23039       164    133      2  madrid     2  portuguese       1    191033
# 23040       478    101      1  madrid     2  portuguese       1    191033
# 23041       185    146      0  madrid     2  portuguese       1    191033
#
#                                        name
# 0        avatar_d_romanian_plusieurs_villes
# 1        avatar_d_romanian_plusieurs_villes
# 2        avatar_d_romanian_plusieurs_villes
# 3        avatar_d_romanian_plusieurs_villes
# 4        avatar_d_romanian_plusieurs_villes
# ...                                     ...
# 23037  avatar_d_portuguese_plusieurs_villes
# 23038  avatar_d_portuguese_plusieurs_villes
# 23039  avatar_d_portuguese_plusieurs_villes
# 23040  avatar_d_portuguese_plusieurs_villes
# 23041  avatar_d_portuguese_plusieurs_villes
#
# [23042 rows x 9 columns]

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []
compteur = 0

for j in range(200):
#for j in range(1) :
    c = random.randint(0,8)
    l = random.randint(0,26)
    d = random.randint(0,35)
    m = random.randint(0,1)
    name = "avatar_d_"+"random_"+str(j)
    params = {
            "avatar_name": name ,
            "language": language[l],
            "city": city[c],
            "date": d,
            "mobile": m,    
    }
    compteur +=1
    print(params)
    
    r1 = requests.post(path(f"avatars/{user_id}/{name}"))
    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(
        pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
    )
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    

    
print(compteur)

pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_1_random = pd.merge(pricing_requests,matrix_avatar_df)
# sub_matrix_1.to_csv('requests_5.csv')
# display(matrix_merge_5)
display(matrix_1_random)
# Out:
# {'avatar_name': 'avatar_d_random_0', 'language': 'belgian', 'city': 'madrid', 'date': 26, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_1', 'language': 'czech', 'city': 'vienna', 'date': 34, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_2', 'language': 'finnish', 'city': 'copenhagen', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_3', 'language': 'estonian', 'city': 'rome', 'date': 3, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_4', 'language': 'hungarian', 'city': 'sofia', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_5', 'language': 'slovene', 'city': 'rome', 'date': 15, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_6', 'language': 'belgian', 'city': 'sofia', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_7', 'language': 'cypriot', 'city': 'amsterdam', 'date': 35, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_8', 'language': 'romanian', 'city': 'copenhagen', 'date': 30, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_9', 'language': 'czech', 'city': 'amsterdam', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_10', 'language': 'hungarian', 'city': 'vilnius', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_11', 'language': 'slovene', 'city': 'copenhagen', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_12', 'language': 'bulgarian', 'city': 'madrid', 'date': 33, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_13', 'language': 'polish', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_14', 'language': 'lithuanian', 'city': 'madrid', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_15', 'language': 'bulgarian', 'city': 'vienna', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_16', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_17', 'language': 'german', 'city': 'vienna', 'date': 28, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_18', 'language': 'danish', 'city': 'copenhagen', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_19', 'language': 'spanish', 'city': 'valletta', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_20', 'language': 'luxembourgish', 'city': 'valletta', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_21', 'language': 'latvian', 'city': 'valletta', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_22', 'language': 'hungarian', 'city': 'valletta', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_23', 'language': 'luxembourgish', 'city': 'valletta', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_24', 'language': 'cypriot', 'city': 'madrid', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_25', 'language': 'greek', 'city': 'rome', 'date': 27, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_26', 'language': 'estonian', 'city': 'copenhagen', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_27', 'language': 'maltese', 'city': 'madrid', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_28', 'language': 'belgian', 'city': 'copenhagen', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_29', 'language': 'latvian', 'city': 'sofia', 'date': 24, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_30', 'language': 'italian', 'city': 'amsterdam', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_31', 'language': 'greek', 'city': 'sofia', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_32', 'language': 'lithuanian', 'city': 'rome', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_33', 'language': 'lithuanian', 'city': 'rome', 'date': 34, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_34', 'language': 'portuguese', 'city': 'valletta', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_35', 'language': 'luxembourgish', 'city': 'rome', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_36', 'language': 'austrian', 'city': 'copenhagen', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_37', 'language': 'danish', 'city': 'vienna', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_38', 'language': 'romanian', 'city': 'vienna', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_39', 'language': 'belgian', 'city': 'sofia', 'date': 17, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_40', 'language': 'finnish', 'city': 'paris', 'date': 33, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_41', 'language': 'slovakian', 'city': 'amsterdam', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_42', 'language': 'romanian', 'city': 'rome', 'date': 30, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_43', 'language': 'austrian', 'city': 'rome', 'date': 27, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_44', 'language': 'czech', 'city': 'vilnius', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_45', 'language': 'estonian', 'city': 'vienna', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_46', 'language': 'cypriot', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_47', 'language': 'estonian', 'city': 'vilnius', 'date': 27, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_48', 'language': 'lithuanian', 'city': 'valletta', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_49', 'language': 'estonian', 'city': 'madrid', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_50', 'language': 'cypriot', 'city': 'sofia', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_51', 'language': 'luxembourgish', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_52', 'language': 'slovene', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_53', 'language': 'belgian', 'city': 'copenhagen', 'date': 3, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_54', 'language': 'slovene', 'city': 'paris', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_55', 'language': 'german', 'city': 'paris', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_56', 'language': 'polish', 'city': 'paris', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_57', 'language': 'irish', 'city': 'paris', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_58', 'language': 'spanish', 'city': 'rome', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_59', 'language': 'dutch', 'city': 'vilnius', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_60', 'language': 'belgian', 'city': 'vienna', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_61', 'language': 'italian', 'city': 'valletta', 'date': 27, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_62', 'language': 'cypriot', 'city': 'vilnius', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_63', 'language': 'polish', 'city': 'vienna', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_64', 'language': 'danish', 'city': 'copenhagen', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_65', 'language': 'spanish', 'city': 'madrid', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_66', 'language': 'spanish', 'city': 'vilnius', 'date': 27, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_67', 'language': 'austrian', 'city': 'madrid', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_68', 'language': 'cypriot', 'city': 'vilnius', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_69', 'language': 'italian', 'city': 'vienna', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_70', 'language': 'slovene', 'city': 'vilnius', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_71', 'language': 'swedish', 'city': 'paris', 'date': 33, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_72', 'language': 'swedish', 'city': 'sofia', 'date': 17, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_73', 'language': 'latvian', 'city': 'vienna', 'date': 6, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_74', 'language': 'latvian', 'city': 'valletta', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_75', 'language': 'danish', 'city': 'vienna', 'date': 31, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_76', 'language': 'irish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_77', 'language': 'austrian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_78', 'language': 'slovakian', 'city': 'valletta', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_79', 'language': 'polish', 'city': 'vilnius', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_80', 'language': 'dutch', 'city': 'vilnius', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_81', 'language': 'danish', 'city': 'amsterdam', 'date': 2, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_82', 'language': 'spanish', 'city': 'rome', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_83', 'language': 'cypriot', 'city': 'amsterdam', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_84', 'language': 'latvian', 'city': 'sofia', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_85', 'language': 'estonian', 'city': 'paris', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_86', 'language': 'maltese', 'city': 'madrid', 'date': 6, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_87', 'language': 'belgian', 'city': 'rome', 'date': 27, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_88', 'language': 'portuguese', 'city': 'vilnius', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_89', 'language': 'finnish', 'city': 'paris', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_90', 'language': 'dutch', 'city': 'paris', 'date': 31, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_91', 'language': 'greek', 'city': 'valletta', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_92', 'language': 'croatian', 'city': 'sofia', 'date': 31, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_93', 'language': 'dutch', 'city': 'vilnius', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_94', 'language': 'romanian', 'city': 'paris', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_95', 'language': 'finnish', 'city': 'copenhagen', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_96', 'language': 'luxembourgish', 'city': 'madrid', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_97', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_98', 'language': 'portuguese', 'city': 'valletta', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_99', 'language': 'swedish', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_100', 'language': 'greek', 'city': 'madrid', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_101', 'language': 'hungarian', 'city': 'madrid', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_102', 'language': 'romanian', 'city': 'paris', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_103', 'language': 'italian', 'city': 'sofia', 'date': 15, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_104', 'language': 'portuguese', 'city': 'valletta', 'date': 31, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_105', 'language': 'finnish', 'city': 'madrid', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_106', 'language': 'belgian', 'city': 'madrid', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_107', 'language': 'french', 'city': 'madrid', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_108', 'language': 'polish', 'city': 'amsterdam', 'date': 16, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_109', 'language': 'polish', 'city': 'sofia', 'date': 27, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_110', 'language': 'german', 'city': 'paris', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_111', 'language': 'romanian', 'city': 'vienna', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_112', 'language': 'polish', 'city': 'copenhagen', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_113', 'language': 'spanish', 'city': 'madrid', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_114', 'language': 'portuguese', 'city': 'amsterdam', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_115', 'language': 'cypriot', 'city': 'paris', 'date': 34, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_116', 'language': 'belgian', 'city': 'madrid', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_117', 'language': 'czech', 'city': 'paris', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_118', 'language': 'croatian', 'city': 'valletta', 'date': 30, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_119', 'language': 'greek', 'city': 'copenhagen', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_120', 'language': 'irish', 'city': 'vilnius', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_121', 'language': 'slovene', 'city': 'rome', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_122', 'language': 'austrian', 'city': 'amsterdam', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_123', 'language': 'finnish', 'city': 'sofia', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_124', 'language': 'luxembourgish', 'city': 'sofia', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_125', 'language': 'finnish', 'city': 'sofia', 'date': 3, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_126', 'language': 'romanian', 'city': 'rome', 'date': 26, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_127', 'language': 'german', 'city': 'paris', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_128', 'language': 'dutch', 'city': 'copenhagen', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_129', 'language': 'hungarian', 'city': 'vilnius', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_130', 'language': 'lithuanian', 'city': 'madrid', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_131', 'language': 'bulgarian', 'city': 'sofia', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_132', 'language': 'greek', 'city': 'madrid', 'date': 33, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_133', 'language': 'german', 'city': 'rome', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_134', 'language': 'swedish', 'city': 'valletta', 'date': 35, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_135', 'language': 'spanish', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# ...
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_159', 'language': 'cypriot', 'city': 'vilnius', 'date': 27, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_160', 'language': 'italian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_161', 'language': 'polish', 'city': 'amsterdam', 'date': 29, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_162', 'language': 'croatian', 'city': 'rome', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_163', 'language': 'czech', 'city': 'madrid', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_164', 'language': 'latvian', 'city': 'madrid', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_165', 'language': 'luxembourgish', 'city': 'rome', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_166', 'language': 'belgian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_167', 'language': 'bulgarian', 'city': 'sofia', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_168', 'language': 'greek', 'city': 'copenhagen', 'date': 14, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_169', 'language': 'slovene', 'city': 'copenhagen', 'date': 16, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_170', 'language': 'austrian', 'city': 'paris', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_171', 'language': 'luxembourgish', 'city': 'valletta', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_172', 'language': 'danish', 'city': 'madrid', 'date': 34, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_173', 'language': 'danish', 'city': 'paris', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_174', 'language': 'estonian', 'city': 'madrid', 'date': 17, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_175', 'language': 'czech', 'city': 'madrid', 'date': 4, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_176', 'language': 'greek', 'city': 'copenhagen', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_177', 'language': 'dutch', 'city': 'sofia', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_178', 'language': 'italian', 'city': 'sofia', 'date': 30, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_179', 'language': 'maltese', 'city': 'madrid', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_180', 'language': 'dutch', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_181', 'language': 'estonian', 'city': 'madrid', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_182', 'language': 'maltese', 'city': 'sofia', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_183', 'language': 'danish', 'city': 'amsterdam', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_184', 'language': 'polish', 'city': 'amsterdam', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_185', 'language': 'hungarian', 'city': 'vilnius', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_186', 'language': 'finnish', 'city': 'amsterdam', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_187', 'language': 'maltese', 'city': 'sofia', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_188', 'language': 'czech', 'city': 'vilnius', 'date': 24, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_189', 'language': 'swedish', 'city': 'vienna', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_190', 'language': 'belgian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_191', 'language': 'bulgarian', 'city': 'sofia', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_192', 'language': 'french', 'city': 'amsterdam', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_193', 'language': 'austrian', 'city': 'amsterdam', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_194', 'language': 'swedish', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_195', 'language': 'estonian', 'city': 'vienna', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_196', 'language': 'swedish', 'city': 'vilnius', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_197', 'language': 'cypriot', 'city': 'sofia', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_198', 'language': 'latvian', 'city': 'rome', 'date': 16, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_199', 'language': 'dutch', 'city': 'copenhagen', 'date': 15, 'mobile': 0}
# 200
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2581975064.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#        hotel_id  price  stock        city  date language  mobile avatar_id  \
# 0           174    130     66      madrid    26  belgian       1    191034
# 1           873    207     77      madrid    26  belgian       1    191034
# 2           378    127      4      madrid    26  belgian       1    191034
# 3             2     90     58      madrid    26  belgian       1    191034
# 4           527    126     38      madrid    26  belgian       1    191034
# ...         ...    ...    ...         ...   ...      ...     ...       ...
# 20959       243     99      0  copenhagen    15    dutch       0    191233
# 20960       922    278     13  copenhagen    15    dutch       0    191233
# 20961       898     94      4  copenhagen    15    dutch       0    191233
# 20962       622    124     17  copenhagen    15    dutch       0    191233
# 20963       523    106     11  copenhagen    15    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 20959  avatar_d_random_199
# 20960  avatar_d_random_199
# 20961  avatar_d_random_199
# 20962  avatar_d_random_199
# 20963  avatar_d_random_199
#
# [20964 rows x 9 columns]

# %%
new_matrix = pd.DataFrame(sub_matrix_1['name'].unique(),columns = ['name'])      
visualisation = pd.merge(new_matrix,matrix_1_random, copy = False)
subset_requests = matrix_1_random[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
print(visualisation.shape)
# Out:
#                       name avatar_id  date   language  mobile        city
# 0        avatar_d_random_0    191034    26    belgian       1      madrid
# 116      avatar_d_random_1    191035    34      czech       1      vienna
# 214      avatar_d_random_2    191036    26    finnish       0  copenhagen
# 358      avatar_d_random_3    191037     3   estonian       0        rome
# 478      avatar_d_random_4    191038     3  hungarian       1       sofia
# ...                    ...       ...   ...        ...     ...         ...
# 20452  avatar_d_random_195    191229    25   estonian       0      vienna
# 20558  avatar_d_random_196    191230     6    swedish       0     vilnius
# 20651  avatar_d_random_197    191231     1    cypriot       0       sofia
# 20703  avatar_d_random_198    191232    16    latvian       1        rome
# 20824  avatar_d_random_199    191233    15      dutch       0  copenhagen
#
# [200 rows x 6 columns]
# (200, 6)

# %%
matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []

compteur = 0
for i in range(visualisation.shape[0]):
# for i in range(1):
    c = random.randint(0,8)
#     if city[c] == visualisation.iloc[i]['city'] :
#         if c == 8 :
#             c -= 1
#         if c == 0 :
#             c += 1
    if visualisation.iloc[i]['date'] - 2 < 0 :

        params = {"avatar_name": visualisation.iloc[i]['name'] ,
                "language": visualisation.iloc[i]['language'],
                "city": city[c]  ,
                "date": 0 ,
                "mobile": visualisation.iloc[i]['mobile'],    
                }
    else :
        params = {"avatar_name": visualisation.iloc[i]['name'] ,
                "language": visualisation.iloc[i]['language'],
                "city": city[c]  ,
                "date": visualisation.iloc[i]['date']-2 ,
                "mobile": visualisation.iloc[i]['mobile'],    
                }
    
    
    print(params)
    compteur += 1

    # avatar_id = visualisation.iloc[i]['avatar_id']
    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],visualisation.iloc[i]['name'])], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
    
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
matrix_3_random = pd.merge(pricing_requests,matrix_avatar_df)
# sub_matrix_1.to_csv('requests_5.csv')
# display(matrix_merge_5)
display(matrix_3_random)
# Out:
# {'avatar_name': 'avatar_d_random_0', 'language': 'belgian', 'city': 'sofia', 'date': 24, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_1', 'language': 'czech', 'city': 'valletta', 'date': 32, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_2', 'language': 'finnish', 'city': 'vienna', 'date': 24, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_3', 'language': 'estonian', 'city': 'vienna', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_4', 'language': 'hungarian', 'city': 'copenhagen', 'date': 1, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_5', 'language': 'slovene', 'city': 'valletta', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_6', 'language': 'belgian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_7', 'language': 'cypriot', 'city': 'vilnius', 'date': 33, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_8', 'language': 'romanian', 'city': 'vilnius', 'date': 28, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_9', 'language': 'czech', 'city': 'rome', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_10', 'language': 'hungarian', 'city': 'valletta', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_11', 'language': 'slovene', 'city': 'madrid', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_12', 'language': 'bulgarian', 'city': 'rome', 'date': 31, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_13', 'language': 'polish', 'city': 'madrid', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_14', 'language': 'lithuanian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_15', 'language': 'bulgarian', 'city': 'madrid', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_16', 'language': 'lithuanian', 'city': 'sofia', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_17', 'language': 'german', 'city': 'vilnius', 'date': 26, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_18', 'language': 'danish', 'city': 'rome', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_19', 'language': 'spanish', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_20', 'language': 'luxembourgish', 'city': 'vilnius', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_21', 'language': 'latvian', 'city': 'sofia', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_22', 'language': 'hungarian', 'city': 'rome', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_23', 'language': 'luxembourgish', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_24', 'language': 'cypriot', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_25', 'language': 'greek', 'city': 'madrid', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_26', 'language': 'estonian', 'city': 'sofia', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_27', 'language': 'maltese', 'city': 'valletta', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_28', 'language': 'belgian', 'city': 'madrid', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_29', 'language': 'latvian', 'city': 'vienna', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_30', 'language': 'italian', 'city': 'vilnius', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_31', 'language': 'greek', 'city': 'sofia', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_32', 'language': 'lithuanian', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_33', 'language': 'lithuanian', 'city': 'valletta', 'date': 32, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_34', 'language': 'portuguese', 'city': 'paris', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_35', 'language': 'luxembourgish', 'city': 'sofia', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_36', 'language': 'austrian', 'city': 'amsterdam', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_37', 'language': 'danish', 'city': 'madrid', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_38', 'language': 'romanian', 'city': 'madrid', 'date': 16, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_39', 'language': 'belgian', 'city': 'vilnius', 'date': 15, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_40', 'language': 'finnish', 'city': 'paris', 'date': 31, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_41', 'language': 'slovakian', 'city': 'vienna', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_42', 'language': 'romanian', 'city': 'valletta', 'date': 28, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_43', 'language': 'austrian', 'city': 'vienna', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_44', 'language': 'czech', 'city': 'sofia', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_45', 'language': 'estonian', 'city': 'vienna', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_46', 'language': 'cypriot', 'city': 'vilnius', 'date': 6, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_47', 'language': 'estonian', 'city': 'rome', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_48', 'language': 'lithuanian', 'city': 'vienna', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_49', 'language': 'estonian', 'city': 'vilnius', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_50', 'language': 'cypriot', 'city': 'amsterdam', 'date': 17, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_51', 'language': 'luxembourgish', 'city': 'madrid', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_52', 'language': 'slovene', 'city': 'madrid', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_53', 'language': 'belgian', 'city': 'valletta', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_54', 'language': 'slovene', 'city': 'copenhagen', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_55', 'language': 'german', 'city': 'madrid', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_56', 'language': 'polish', 'city': 'vilnius', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_57', 'language': 'irish', 'city': 'paris', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_58', 'language': 'spanish', 'city': 'copenhagen', 'date': 4, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_59', 'language': 'dutch', 'city': 'rome', 'date': 7, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_60', 'language': 'belgian', 'city': 'sofia', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_61', 'language': 'italian', 'city': 'madrid', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_62', 'language': 'cypriot', 'city': 'madrid', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_63', 'language': 'polish', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_64', 'language': 'danish', 'city': 'rome', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_65', 'language': 'spanish', 'city': 'vienna', 'date': 18, 'mobile': 0}
# {'avatar_name': 'avatar_d_random_66', 'language': 'spanish', 'city': 'rome', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_67', 'language': 'austrian', 'city': 'vienna', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_68', 'language': 'cypriot', 'city': 'valletta', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_69', 'language': 'italian', 'city': 'madrid', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_70', 'language': 'slovene', 'city': 'sofia', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_71', 'language': 'swedish', 'city': 'paris', 'date': 31, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_72', 'language': 'swedish', 'city': 'amsterdam', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_73', 'language': 'latvian', 'city': 'vilnius', 'date': 4, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_74', 'language': 'latvian', 'city': 'vienna', 'date': 4, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_75', 'language': 'danish', 'city': 'copenhagen', 'date': 29, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_76', 'language': 'irish', 'city': 'vilnius', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_77', 'language': 'austrian', 'city': 'copenhagen', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_78', 'language': 'slovakian', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_79', 'language': 'polish', 'city': 'rome', 'date': 6, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_80', 'language': 'dutch', 'city': 'amsterdam', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_81', 'language': 'danish', 'city': 'rome', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_82', 'language': 'spanish', 'city': 'sofia', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_83', 'language': 'cypriot', 'city': 'vilnius', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_84', 'language': 'latvian', 'city': 'paris', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_85', 'language': 'estonian', 'city': 'paris', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_86', 'language': 'maltese', 'city': 'copenhagen', 'date': 4, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_87', 'language': 'belgian', 'city': 'madrid', 'date': 25, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_88', 'language': 'portuguese', 'city': 'paris', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_89', 'language': 'finnish', 'city': 'copenhagen', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_90', 'language': 'dutch', 'city': 'madrid', 'date': 29, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_91', 'language': 'greek', 'city': 'vienna', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_92', 'language': 'croatian', 'city': 'amsterdam', 'date': 29, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_93', 'language': 'dutch', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_94', 'language': 'romanian', 'city': 'sofia', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_95', 'language': 'finnish', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_96', 'language': 'luxembourgish', 'city': 'rome', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_97', 'language': 'luxembourgish', 'city': 'madrid', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_98', 'language': 'portuguese', 'city': 'vilnius', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_99', 'language': 'swedish', 'city': 'paris', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_100', 'language': 'greek', 'city': 'vilnius', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_101', 'language': 'hungarian', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_102', 'language': 'romanian', 'city': 'vilnius', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_103', 'language': 'italian', 'city': 'sofia', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_104', 'language': 'portuguese', 'city': 'valletta', 'date': 29, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_105', 'language': 'finnish', 'city': 'sofia', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_106', 'language': 'belgian', 'city': 'valletta', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_107', 'language': 'french', 'city': 'vilnius', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_108', 'language': 'polish', 'city': 'amsterdam', 'date': 14, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_109', 'language': 'polish', 'city': 'valletta', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_110', 'language': 'german', 'city': 'vienna', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_111', 'language': 'romanian', 'city': 'paris', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_112', 'language': 'polish', 'city': 'vienna', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_113', 'language': 'spanish', 'city': 'madrid', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_114', 'language': 'portuguese', 'city': 'amsterdam', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_115', 'language': 'cypriot', 'city': 'vilnius', 'date': 32, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_116', 'language': 'belgian', 'city': 'copenhagen', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_117', 'language': 'czech', 'city': 'madrid', 'date': 17, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_118', 'language': 'croatian', 'city': 'sofia', 'date': 28, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_119', 'language': 'greek', 'city': 'paris', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_120', 'language': 'irish', 'city': 'madrid', 'date': 13, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_121', 'language': 'slovene', 'city': 'paris', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_122', 'language': 'austrian', 'city': 'paris', 'date': 5, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_123', 'language': 'finnish', 'city': 'amsterdam', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_124', 'language': 'luxembourgish', 'city': 'valletta', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_125', 'language': 'finnish', 'city': 'madrid', 'date': 1, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_126', 'language': 'romanian', 'city': 'paris', 'date': 24, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_127', 'language': 'german', 'city': 'amsterdam', 'date': 28, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_128', 'language': 'dutch', 'city': 'copenhagen', 'date': 30, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_129', 'language': 'hungarian', 'city': 'valletta', 'date': 4, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_130', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_131', 'language': 'bulgarian', 'city': 'paris', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_132', 'language': 'greek', 'city': 'amsterdam', 'date': 31, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_133', 'language': 'german', 'city': 'amsterdam', 'date': 1, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_134', 'language': 'swedish', 'city': 'rome', 'date': 33, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_135', 'language': 'spanish', 'city': 'vilnius', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# ...
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_159', 'language': 'cypriot', 'city': 'paris', 'date': 25, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_160', 'language': 'italian', 'city': 'copenhagen', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_161', 'language': 'polish', 'city': 'vilnius', 'date': 27, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_162', 'language': 'croatian', 'city': 'vienna', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_163', 'language': 'czech', 'city': 'vienna', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_164', 'language': 'latvian', 'city': 'sofia', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_165', 'language': 'luxembourgish', 'city': 'paris', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_166', 'language': 'belgian', 'city': 'madrid', 'date': 0, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_167', 'language': 'bulgarian', 'city': 'sofia', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_168', 'language': 'greek', 'city': 'sofia', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_169', 'language': 'slovene', 'city': 'rome', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_170', 'language': 'austrian', 'city': 'valletta', 'date': 3, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_171', 'language': 'luxembourgish', 'city': 'valletta', 'date': 26, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_172', 'language': 'danish', 'city': 'valletta', 'date': 32, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_173', 'language': 'danish', 'city': 'amsterdam', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_174', 'language': 'estonian', 'city': 'valletta', 'date': 15, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_175', 'language': 'czech', 'city': 'paris', 'date': 2, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_176', 'language': 'greek', 'city': 'copenhagen', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_177', 'language': 'dutch', 'city': 'vilnius', 'date': 3, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_178', 'language': 'italian', 'city': 'paris', 'date': 28, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_179', 'language': 'maltese', 'city': 'vilnius', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_180', 'language': 'dutch', 'city': 'vienna', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_181', 'language': 'estonian', 'city': 'copenhagen', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_182', 'language': 'maltese', 'city': 'madrid', 'date': 7, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_183', 'language': 'danish', 'city': 'vilnius', 'date': 23, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_184', 'language': 'polish', 'city': 'copenhagen', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_185', 'language': 'hungarian', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_186', 'language': 'finnish', 'city': 'amsterdam', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_187', 'language': 'maltese', 'city': 'vienna', 'date': 5, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_188', 'language': 'czech', 'city': 'madrid', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_189', 'language': 'swedish', 'city': 'vilnius', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_190', 'language': 'belgian', 'city': 'vienna', 'date': 17, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_191', 'language': 'bulgarian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_192', 'language': 'french', 'city': 'madrid', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_193', 'language': 'austrian', 'city': 'madrid', 'date': 24, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_194', 'language': 'swedish', 'city': 'sofia', 'date': 16, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_195', 'language': 'estonian', 'city': 'copenhagen', 'date': 23, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_196', 'language': 'swedish', 'city': 'copenhagen', 'date': 4, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_197', 'language': 'cypriot', 'city': 'valletta', 'date': 0, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_198', 'language': 'latvian', 'city': 'vienna', 'date': 14, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_random_199', 'language': 'dutch', 'city': 'amsterdam', 'date': 13, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22464\2047666339.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#        hotel_id  price  stock       city  date language  mobile avatar_id  \
# 0           814    148     64      sofia    24  belgian       1    191034
# 1            25    149     59      sofia    24  belgian       1    191034
# 2           470     70     23      sofia    24  belgian       1    191034
# 3           553    102     20      sofia    24  belgian       1    191034
# 4           145     91     33      sofia    24  belgian       1    191034
# ...         ...    ...    ...        ...   ...      ...     ...       ...
# 20575       460     83      0  amsterdam    13    dutch       0    191233
# 20576       103    180     34  amsterdam    13    dutch       0    191233
# 20577       548    227     41  amsterdam    13    dutch       0    191233
# 20578       307    125     10  amsterdam    13    dutch       0    191233
# 20579       111    145      7  amsterdam    13    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 20575  avatar_d_random_199
# 20576  avatar_d_random_199
# 20577  avatar_d_random_199
# 20578  avatar_d_random_199
# 20579  avatar_d_random_199
#
# [20580 rows x 9 columns]

# %%
display(matrix_1_random)
display(matrix_2_random)
display(matrix_3_random)
# Out:
#        hotel_id  price  stock        city  date language  mobile avatar_id  \
# 0           174    130     66      madrid    26  belgian       1    191034
# 1           873    207     77      madrid    26  belgian       1    191034
# 2           378    127      4      madrid    26  belgian       1    191034
# 3             2     90     58      madrid    26  belgian       1    191034
# 4           527    126     38      madrid    26  belgian       1    191034
# ...         ...    ...    ...         ...   ...      ...     ...       ...
# 20959       243     99      0  copenhagen    15    dutch       0    191233
# 20960       922    278     13  copenhagen    15    dutch       0    191233
# 20961       898     94      4  copenhagen    15    dutch       0    191233
# 20962       622    124     17  copenhagen    15    dutch       0    191233
# 20963       523    106     11  copenhagen    15    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 20959  avatar_d_random_199
# 20960  avatar_d_random_199
# 20961  avatar_d_random_199
# 20962  avatar_d_random_199
# 20963  avatar_d_random_199
#
# [20964 rows x 9 columns]
#        hotel_id  price  stock   city  date language  mobile avatar_id  \
# 0           802     86     35  sofia    26  belgian       1    191034
# 1           337     86     45  sofia    26  belgian       1    191034
# 2           578    105     56  sofia    26  belgian       1    191034
# 3           137     48     17  sofia    26  belgian       1    191034
# 4           272     51     15  sofia    26  belgian       1    191034
# ...         ...    ...    ...    ...   ...      ...     ...       ...
# 21571       374    102      0   rome    15    dutch       0    191233
# 21572       489    318     25   rome    15    dutch       0    191233
# 21573       381    135      2   rome    15    dutch       0    191233
# 21574       180     74      2   rome    15    dutch       0    191233
# 21575       840    107     20   rome    15    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 21571  avatar_d_random_199
# 21572  avatar_d_random_199
# 21573  avatar_d_random_199
# 21574  avatar_d_random_199
# 21575  avatar_d_random_199
#
# [21576 rows x 9 columns]
#        hotel_id  price  stock       city  date language  mobile avatar_id  \
# 0           814    148     64      sofia    24  belgian       1    191034
# 1            25    149     59      sofia    24  belgian       1    191034
# 2           470     70     23      sofia    24  belgian       1    191034
# 3           553    102     20      sofia    24  belgian       1    191034
# 4           145     91     33      sofia    24  belgian       1    191034
# ...         ...    ...    ...        ...   ...      ...     ...       ...
# 20575       460     83      0  amsterdam    13    dutch       0    191233
# 20576       103    180     34  amsterdam    13    dutch       0    191233
# 20577       548    227     41  amsterdam    13    dutch       0    191233
# 20578       307    125     10  amsterdam    13    dutch       0    191233
# 20579       111    145      7  amsterdam    13    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 20575  avatar_d_random_199
# 20576  avatar_d_random_199
# 20577  avatar_d_random_199
# 20578  avatar_d_random_199
# 20579  avatar_d_random_199
#
# [20580 rows x 9 columns]

# %%
requets6_part_2= pd.concat([matrix_1_random,matrix_2_random,matrix_3_random], ignore_index=True)
display(requets6_part_2)
requets6_part_2.to_csv('requests6_part_2.csv')
# Out:
#        hotel_id  price  stock       city  date language  mobile avatar_id  \
# 0           174    130     66     madrid    26  belgian       1    191034
# 1           873    207     77     madrid    26  belgian       1    191034
# 2           378    127      4     madrid    26  belgian       1    191034
# 3             2     90     58     madrid    26  belgian       1    191034
# 4           527    126     38     madrid    26  belgian       1    191034
# ...         ...    ...    ...        ...   ...      ...     ...       ...
# 63115       460     83      0  amsterdam    13    dutch       0    191233
# 63116       103    180     34  amsterdam    13    dutch       0    191233
# 63117       548    227     41  amsterdam    13    dutch       0    191233
# 63118       307    125     10  amsterdam    13    dutch       0    191233
# 63119       111    145      7  amsterdam    13    dutch       0    191233
#
#                       name
# 0        avatar_d_random_0
# 1        avatar_d_random_0
# 2        avatar_d_random_0
# 3        avatar_d_random_0
# 4        avatar_d_random_0
# ...                    ...
# 63115  avatar_d_random_199
# 63116  avatar_d_random_199
# 63117  avatar_d_random_199
# 63118  avatar_d_random_199
# 63119  avatar_d_random_199
#
# [63120 rows x 9 columns]

# %%
Features.city.unique()
# Out:
# array(['paris', 'copenhagen', 'madrid', 'rome', 'sofia', 'vilnius',
#        'vienna', 'amsterdam', 'valletta'], dtype=object)

# %%
#Premier script 

# compteur = 0
# i = 0
# step = ['step7j_','step3j_']

# # MOBILE 0, départ 36e jour avec step 7 jours
# date = [36,16]
# mobile = [0,1]

# matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
# pricing_requests = []

# for h in range(2):
#     for i in range(2):
#         for j in range(np.shape(language)[0]):
#             for k in range(np.shape(city)[0]):
#                 a = random.randint(-2,2)
#                 name = "avatar_d"+str(date[i] + a)+ '_'+str(step[i]) + str(mobile[h]) + '_' +str(compteur)
#                 params = {
#                     "avatar_name": name ,
#                     "language": language[j],
#                     "city": city[k],
#                     "date": date[i] + a,
#                     "mobile": mobile[h],    
#                 }
#                 compteur +=1
#                 print(params)
    
#                 r1 = requests.post(path(f"avatars/{user_id}/{name}"))
#                 r1 = requests.get(path(f"pricing/{user_id}"), params=params)
#                 pricing_requests.append(
#                     pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
#                 )
#                 df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
#                 matrix_avatar = matrix_avatar.append(df_tmp)
                
                
# pricing_requests = pd.concat(pricing_requests)
# matrix_avatar_df = pd.DataFrame(matrix_avatar)
# matrix_merge = pd.merge(pricing_requests,matrix_avatar_df)
# matrix_merge.to_csv('matrix_merge.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28884\172598296.py in <module>
# ----> 1 resquests_1
#
# NameError: name 'resquests_1' is not defined

# %% [markdown]
# ### Requests 7

# %%
cities_expensive = ['paris', 'copenhagen', 'amsterdam']
cities_cheap = ['sofia', 'vilnius', 'madrid']
cities_price_mean = ['valletta', 'rome', 'vienna']
date_list = [20,10]

matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []
compteur = 0

for w in range(6):
    for j in range(np.shape(language)[0]):
        for h in range(2):
            a = random.randint(-2,2)
            b = random.randint(0,1)
            name = "avatar_d_"+str(language[j])+"_price_mean_villes"+"_date_"+str(date_list[h] + a)
            params = {"avatar_name": name ,
                    "language": language[j],
                    "city": cities_price_mean[0],
                    "date": date_list[h] + a,
                    "mobile": b}
            print(params)

            r1 = requests.post(path(f"avatars/{user_id}/{name}"))
            r1 = requests.get(path(f"pricing/{user_id}"), params=params)
            pricing_requests.append(
                pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request'])
            )
            df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
            matrix_avatar = matrix_avatar.append(df_tmp)
            
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
sub_matrix_9 = pd.merge(pricing_requests,matrix_avatar_df)
sub_matrix_9.to_csv('requests_9_part1.csv')
display(sub_matrix_9)
# Out:
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_21', 'language': 'romanian', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_9', 'language': 'romanian', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_20', 'language': 'swedish', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_11', 'language': 'swedish', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_22', 'language': 'maltese', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_12', 'language': 'maltese', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_19', 'language': 'belgian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_11', 'language': 'belgian', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_20', 'language': 'luxembourgish', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_11', 'language': 'luxembourgish', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_22', 'language': 'dutch', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_11', 'language': 'dutch', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_18', 'language': 'french', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_10', 'language': 'french', 'city': 'valletta', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_20', 'language': 'finnish', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_11', 'language': 'finnish', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_21', 'language': 'austrian', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_11', 'language': 'austrian', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_18', 'language': 'slovakian', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_12', 'language': 'slovakian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_18', 'language': 'hungarian', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_12', 'language': 'hungarian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_18', 'language': 'bulgarian', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_8', 'language': 'bulgarian', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_20', 'language': 'danish', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_11', 'language': 'danish', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_22', 'language': 'greek', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_8', 'language': 'greek', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_18', 'language': 'croatian', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_9', 'language': 'croatian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_19', 'language': 'polish', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_9', 'language': 'polish', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_21', 'language': 'german', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_11', 'language': 'german', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_18', 'language': 'spanish', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_8', 'language': 'spanish', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_19', 'language': 'estonian', 'city': 'valletta', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_11', 'language': 'estonian', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_20', 'language': 'lithuanian', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_10', 'language': 'lithuanian', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_21', 'language': 'cypriot', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_12', 'language': 'cypriot', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_20', 'language': 'latvian', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_8', 'language': 'latvian', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_22', 'language': 'irish', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_9', 'language': 'irish', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_22', 'language': 'italian', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_8', 'language': 'italian', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_18', 'language': 'slovene', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_10', 'language': 'slovene', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_21', 'language': 'czech', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_8', 'language': 'czech', 'city': 'valletta', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_22', 'language': 'portuguese', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_12', 'language': 'portuguese', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_22', 'language': 'romanian', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_10', 'language': 'romanian', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_18', 'language': 'swedish', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_9', 'language': 'swedish', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_18', 'language': 'maltese', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_12', 'language': 'maltese', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_22', 'language': 'belgian', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_8', 'language': 'belgian', 'city': 'valletta', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_22', 'language': 'luxembourgish', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_9', 'language': 'luxembourgish', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_21', 'language': 'dutch', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_9', 'language': 'dutch', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_22', 'language': 'french', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_11', 'language': 'french', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_20', 'language': 'finnish', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_8', 'language': 'finnish', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_19', 'language': 'austrian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_11', 'language': 'austrian', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_19', 'language': 'slovakian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_12', 'language': 'slovakian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_18', 'language': 'hungarian', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_10', 'language': 'hungarian', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_20', 'language': 'bulgarian', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_12', 'language': 'bulgarian', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_22', 'language': 'danish', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_9', 'language': 'danish', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_21', 'language': 'greek', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_9', 'language': 'greek', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_22', 'language': 'croatian', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_11', 'language': 'croatian', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_22', 'language': 'polish', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_9', 'language': 'polish', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_19', 'language': 'german', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_8', 'language': 'german', 'city': 'valletta', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_19', 'language': 'spanish', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_10', 'language': 'spanish', 'city': 'valletta', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_20', 'language': 'estonian', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_12', 'language': 'estonian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_20', 'language': 'lithuanian', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_8', 'language': 'lithuanian', 'city': 'valletta', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_19', 'language': 'cypriot', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_11', 'language': 'cypriot', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_18', 'language': 'latvian', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_9', 'language': 'latvian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_18', 'language': 'irish', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_10', 'language': 'irish', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_18', 'language': 'italian', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_12', 'language': 'italian', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_18', 'language': 'slovene', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_8', 'language': 'slovene', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_20', 'language': 'czech', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_9', 'language': 'czech', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_21', 'language': 'portuguese', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_11', 'language': 'portuguese', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_21', 'language': 'romanian', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_12', 'language': 'romanian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_22', 'language': 'swedish', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_11', 'language': 'swedish', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_18', 'language': 'maltese', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_9', 'language': 'maltese', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_19', 'language': 'belgian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_8', 'language': 'belgian', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_20', 'language': 'luxembourgish', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_10', 'language': 'luxembourgish', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_22', 'language': 'dutch', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_12', 'language': 'dutch', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_20', 'language': 'french', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_12', 'language': 'french', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_20', 'language': 'finnish', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_8', 'language': 'finnish', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_22', 'language': 'austrian', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_8', 'language': 'austrian', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_22', 'language': 'slovakian', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_8', 'language': 'slovakian', 'city': 'valletta', 'date': 8, 'mobile': 0}
# ...
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_19', 'language': 'austrian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_8', 'language': 'austrian', 'city': 'valletta', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_21', 'language': 'slovakian', 'city': 'valletta', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_12', 'language': 'slovakian', 'city': 'valletta', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_19', 'language': 'hungarian', 'city': 'valletta', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_10', 'language': 'hungarian', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_19', 'language': 'bulgarian', 'city': 'valletta', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_9', 'language': 'bulgarian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_21', 'language': 'danish', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_10', 'language': 'danish', 'city': 'valletta', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_20', 'language': 'greek', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_11', 'language': 'greek', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_22', 'language': 'croatian', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_9', 'language': 'croatian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_22', 'language': 'polish', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_10', 'language': 'polish', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_19', 'language': 'german', 'city': 'valletta', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_11', 'language': 'german', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_22', 'language': 'spanish', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_8', 'language': 'spanish', 'city': 'valletta', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_22', 'language': 'estonian', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_11', 'language': 'estonian', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_19', 'language': 'lithuanian', 'city': 'valletta', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_9', 'language': 'lithuanian', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_22', 'language': 'cypriot', 'city': 'valletta', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_9', 'language': 'cypriot', 'city': 'valletta', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_20', 'language': 'latvian', 'city': 'valletta', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_12', 'language': 'latvian', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_18', 'language': 'irish', 'city': 'valletta', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_11', 'language': 'irish', 'city': 'valletta', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_21', 'language': 'italian', 'city': 'valletta', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_10', 'language': 'italian', 'city': 'valletta', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_18', 'language': 'slovene', 'city': 'valletta', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_11', 'language': 'slovene', 'city': 'valletta', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_20', 'language': 'czech', 'city': 'valletta', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_9', 'language': 'czech', 'city': 'valletta', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_22', 'language': 'portuguese', 'city': 'valletta', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_12', 'language': 'portuguese', 'city': 'valletta', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\51844470.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#        hotel_id  price  stock      city  date  language  mobile avatar_id  \
# 0           466    136     23  valletta    21  romanian       1    300211
# 1           466    136     23  valletta    21  romanian       1    300211
# 2           466    136     23  valletta    21  romanian       1    300211
# 3           746    154     32  valletta    21  romanian       1    300211
# 4           746    154     32  valletta    21  romanian       1    300211
# ...         ...    ...    ...       ...   ...       ...     ...       ...
# 31789       106    150     22  valletta    21   italian       1    300406
# 31790       719    149     48  valletta    21   italian       1    300406
# 31791       709    135     16  valletta    21   italian       1    300406
# 31792       480     71     11  valletta    21   italian       1    300406
# 31793       749    112      8  valletta    21   italian       1    300406
#
#                                               name
# 0      avatar_d_romanian_price_mean_villes_date_21
# 1      avatar_d_romanian_price_mean_villes_date_21
# 2      avatar_d_romanian_price_mean_villes_date_21
# 3      avatar_d_romanian_price_mean_villes_date_21
# 4      avatar_d_romanian_price_mean_villes_date_21
# ...                                            ...
# 31789   avatar_d_italian_price_mean_villes_date_21
# 31790   avatar_d_italian_price_mean_villes_date_21
# 31791   avatar_d_italian_price_mean_villes_date_21
# 31792   avatar_d_italian_price_mean_villes_date_21
# 31793   avatar_d_italian_price_mean_villes_date_21
#
# [31794 rows x 9 columns]

# %%
new_matrix = pd.DataFrame(sub_matrix_9['name'].unique(),columns = ['name'])      
visualisation = pd.merge(new_matrix,sub_matrix_9, copy = False)
subset_requests = sub_matrix_9[['name', 'avatar_id', 'date', 'language', 'mobile', 'city']]
visualisation = subset_requests.drop_duplicates()
display(visualisation)
print(visualisation.shape)
# Out:
#                                               name avatar_id  date  language  \
# 0      avatar_d_romanian_price_mean_villes_date_21    300211    21  romanian
# 138    avatar_d_romanian_price_mean_villes_date_21    300211    21  romanian
# 414     avatar_d_romanian_price_mean_villes_date_9    300212     9  romanian
# 462     avatar_d_swedish_price_mean_villes_date_20    300213    20   swedish
# 508     avatar_d_swedish_price_mean_villes_date_11    300214    11   swedish
# ...                                            ...       ...   ...       ...
# 31556  avatar_d_estonian_price_mean_villes_date_22    300402    22  estonian
# 31604   avatar_d_cypriot_price_mean_villes_date_22    300403    22   cypriot
# 31652    avatar_d_cypriot_price_mean_villes_date_9    300404     9   cypriot
# 31700   avatar_d_latvian_price_mean_villes_date_12    300405    12   latvian
# 31748   avatar_d_italian_price_mean_villes_date_21    300406    21   italian
#
#        mobile      city
# 0           1  valletta
# 138         0  valletta
# 414         0  valletta
# 462         1  valletta
# 508         0  valletta
# ...       ...       ...
# 31556       1  valletta
# 31604       0  valletta
# 31652       0  valletta
# 31700       0  valletta
# 31748       1  valletta
#
# [247 rows x 6 columns]
# (247, 6)

# %%
cities_expensive = ['paris', 'copenhagen', 'amsterdam']
cities_cheap = ['sofia', 'vilnius', 'madrid']
cities_price_mean = ['valletta', 'rome', 'vienna']
date_list = [20,10]

matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []
compteur = 0

for i in range(visualisation.shape[0]):
    
    params = {"avatar_name": visualisation.iloc[i]['name'] ,
                "language": visualisation.iloc[i]['language'],
                "city": cities_price_mean[1]  ,
                "date": visualisation.iloc[i]['date'] ,
                "mobile": visualisation.iloc[i]['mobile'],    
                }
    print(params)

    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
            
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
sub_matrix_9_part2 = pd.merge(pricing_requests,matrix_avatar_df)
sub_matrix_9_part2.to_csv('requests_9_part2.csv')
display(sub_matrix_9_part2)
# Out:
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_21', 'language': 'romanian', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_21', 'language': 'romanian', 'city': 'rome', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_9', 'language': 'romanian', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_20', 'language': 'swedish', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_11', 'language': 'swedish', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_11', 'language': 'swedish', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_22', 'language': 'maltese', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_12', 'language': 'maltese', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_12', 'language': 'maltese', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_19', 'language': 'belgian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_11', 'language': 'belgian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_20', 'language': 'luxembourgish', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_11', 'language': 'luxembourgish', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_22', 'language': 'dutch', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_22', 'language': 'dutch', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_11', 'language': 'dutch', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_18', 'language': 'french', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_10', 'language': 'french', 'city': 'rome', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_20', 'language': 'finnish', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_20', 'language': 'finnish', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_11', 'language': 'finnish', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_21', 'language': 'austrian', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_11', 'language': 'austrian', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_11', 'language': 'austrian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_18', 'language': 'slovakian', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_12', 'language': 'slovakian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_12', 'language': 'slovakian', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_18', 'language': 'hungarian', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_12', 'language': 'hungarian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_18', 'language': 'bulgarian', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_18', 'language': 'bulgarian', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_8', 'language': 'bulgarian', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_8', 'language': 'bulgarian', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_20', 'language': 'danish', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_11', 'language': 'danish', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_22', 'language': 'greek', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_8', 'language': 'greek', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_18', 'language': 'croatian', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_18', 'language': 'croatian', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_9', 'language': 'croatian', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_19', 'language': 'polish', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_9', 'language': 'polish', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_9', 'language': 'polish', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_21', 'language': 'german', 'city': 'rome', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_11', 'language': 'german', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_18', 'language': 'spanish', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_8', 'language': 'spanish', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_19', 'language': 'estonian', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_19', 'language': 'estonian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_11', 'language': 'estonian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_11', 'language': 'estonian', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_20', 'language': 'lithuanian', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_10', 'language': 'lithuanian', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_10', 'language': 'lithuanian', 'city': 'rome', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_21', 'language': 'cypriot', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_12', 'language': 'cypriot', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_20', 'language': 'latvian', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_8', 'language': 'latvian', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_8', 'language': 'latvian', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_22', 'language': 'irish', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_22', 'language': 'irish', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_9', 'language': 'irish', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_22', 'language': 'italian', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_8', 'language': 'italian', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_18', 'language': 'slovene', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_18', 'language': 'slovene', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovene_price_mean_villes_date_10', 'language': 'slovene', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_21', 'language': 'czech', 'city': 'rome', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_8', 'language': 'czech', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_22', 'language': 'portuguese', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_12', 'language': 'portuguese', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_12', 'language': 'portuguese', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_22', 'language': 'romanian', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_10', 'language': 'romanian', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_romanian_price_mean_villes_date_10', 'language': 'romanian', 'city': 'rome', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_18', 'language': 'swedish', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_9', 'language': 'swedish', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_18', 'language': 'maltese', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_18', 'language': 'maltese', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_22', 'language': 'belgian', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_8', 'language': 'belgian', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_8', 'language': 'belgian', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_22', 'language': 'luxembourgish', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_9', 'language': 'luxembourgish', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_9', 'language': 'luxembourgish', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_21', 'language': 'dutch', 'city': 'rome', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_21', 'language': 'dutch', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_9', 'language': 'dutch', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_dutch_price_mean_villes_date_9', 'language': 'dutch', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_22', 'language': 'french', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_11', 'language': 'french', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_11', 'language': 'french', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_8', 'language': 'finnish', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_19', 'language': 'austrian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_19', 'language': 'slovakian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_10', 'language': 'hungarian', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_20', 'language': 'bulgarian', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_12', 'language': 'bulgarian', 'city': 'rome', 'date': 12, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_22', 'language': 'danish', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_22', 'language': 'danish', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_9', 'language': 'danish', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_9', 'language': 'danish', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_21', 'language': 'greek', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_9', 'language': 'greek', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_22', 'language': 'croatian', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_22', 'language': 'croatian', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_11', 'language': 'croatian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_22', 'language': 'polish', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_22', 'language': 'polish', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_19', 'language': 'german', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_19', 'language': 'german', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_german_price_mean_villes_date_8', 'language': 'german', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_19', 'language': 'spanish', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_19', 'language': 'spanish', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_10', 'language': 'spanish', 'city': 'rome', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_20', 'language': 'estonian', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_20', 'language': 'estonian', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_12', 'language': 'estonian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_8', 'language': 'lithuanian', 'city': 'rome', 'date': 8, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_19', 'language': 'cypriot', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_19', 'language': 'cypriot', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_11', 'language': 'cypriot', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_18', 'language': 'latvian', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_9', 'language': 'latvian', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_18', 'language': 'irish', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_18', 'language': 'irish', 'city': 'rome', 'date': 18, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_10', 'language': 'irish', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_18', 'language': 'italian', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# ...
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_french_price_mean_villes_date_9', 'language': 'french', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_22', 'language': 'finnish', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_finnish_price_mean_villes_date_12', 'language': 'finnish', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_austrian_price_mean_villes_date_20', 'language': 'austrian', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_20', 'language': 'slovakian', 'city': 'rome', 'date': 20, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_19', 'language': 'danish', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_19', 'language': 'greek', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_croatian_price_mean_villes_date_19', 'language': 'croatian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_8', 'language': 'polish', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_11', 'language': 'spanish', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_19', 'language': 'lithuanian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_19', 'language': 'lithuanian', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_lithuanian_price_mean_villes_date_9', 'language': 'lithuanian', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_10', 'language': 'cypriot', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_11', 'language': 'latvian', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_irish_price_mean_villes_date_20', 'language': 'irish', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_18', 'language': 'czech', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_czech_price_mean_villes_date_10', 'language': 'czech', 'city': 'rome', 'date': 10, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_portuguese_price_mean_villes_date_8', 'language': 'portuguese', 'city': 'rome', 'date': 8, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_swedish_price_mean_villes_date_19', 'language': 'swedish', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_20', 'language': 'maltese', 'city': 'rome', 'date': 20, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_maltese_price_mean_villes_date_11', 'language': 'maltese', 'city': 'rome', 'date': 11, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_belgian_price_mean_villes_date_12', 'language': 'belgian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_18', 'language': 'luxembourgish', 'city': 'rome', 'date': 18, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_luxembourgish_price_mean_villes_date_12', 'language': 'luxembourgish', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_slovakian_price_mean_villes_date_21', 'language': 'slovakian', 'city': 'rome', 'date': 21, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_hungarian_price_mean_villes_date_19', 'language': 'hungarian', 'city': 'rome', 'date': 19, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_19', 'language': 'bulgarian', 'city': 'rome', 'date': 19, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_bulgarian_price_mean_villes_date_9', 'language': 'bulgarian', 'city': 'rome', 'date': 9, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_danish_price_mean_villes_date_21', 'language': 'danish', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_greek_price_mean_villes_date_11', 'language': 'greek', 'city': 'rome', 'date': 11, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_polish_price_mean_villes_date_10', 'language': 'polish', 'city': 'rome', 'date': 10, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_spanish_price_mean_villes_date_22', 'language': 'spanish', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_estonian_price_mean_villes_date_22', 'language': 'estonian', 'city': 'rome', 'date': 22, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_22', 'language': 'cypriot', 'city': 'rome', 'date': 22, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_cypriot_price_mean_villes_date_9', 'language': 'cypriot', 'city': 'rome', 'date': 9, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_latvian_price_mean_villes_date_12', 'language': 'latvian', 'city': 'rome', 'date': 12, 'mobile': 0}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# {'avatar_name': 'avatar_d_italian_price_mean_villes_date_21', 'language': 'italian', 'city': 'rome', 'date': 21, 'mobile': 1}
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\2897103474.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#        hotel_id  price  stock  city  date  language  mobile avatar_id  \
# 0           786    219     46  rome    21  romanian       1    300211
# 1           786    219     46  rome    21  romanian       1    300211
# 2           399    170     29  rome    21  romanian       1    300211
# 3           399    170     29  rome    21  romanian       1    300211
# 4           341    105     19  rome    21  romanian       1    300211
# ...         ...    ...    ...   ...   ...       ...     ...       ...
# 43922       374    100      6  rome    21   italian       1    300406
# 43923       381    132     20  rome    21   italian       1    300406
# 43924       774    165     31  rome    21   italian       1    300406
# 43925       686     84     14  rome    21   italian       1    300406
# 43926         3     67     12  rome    21   italian       1    300406
#
#                                                 name
# 0      avatar_d_portuguese_price_mean_villes_date_12
# 1      avatar_d_portuguese_price_mean_villes_date_12
# 2      avatar_d_portuguese_price_mean_villes_date_12
# 3      avatar_d_portuguese_price_mean_villes_date_12
# 4      avatar_d_portuguese_price_mean_villes_date_12
# ...                                              ...
# 43922  avatar_d_portuguese_price_mean_villes_date_12
# 43923  avatar_d_portuguese_price_mean_villes_date_12
# 43924  avatar_d_portuguese_price_mean_villes_date_12
# 43925  avatar_d_portuguese_price_mean_villes_date_12
# 43926  avatar_d_portuguese_price_mean_villes_date_12
#
# [43927 rows x 9 columns]

# %%
cities_expensive = ['paris', 'copenhagen', 'amsterdam']
cities_cheap = ['sofia', 'vilnius', 'madrid']
cities_price_mean = ['valletta', 'rome', 'vienna']
date_list = [20,10]

matrix_avatar = pd.DataFrame([],columns = ['avatar_id', 'name'])
pricing_requests = []
compteur = 0

for i in range(visualisation.shape[0]):
    
    params = {"avatar_name": visualisation.iloc[i]['name'] ,
                "language": visualisation.iloc[i]['language'],
                "city": cities_price_mean[2]  ,
                "date": visualisation.iloc[i]['date'] ,
                "mobile": visualisation.iloc[i]['mobile'],    
                }
#     print(params)

    r1 = requests.get(path(f"pricing/{user_id}"), params=params)
    pricing_requests.append(pd.DataFrame(r1.json()['prices']).assign(**r1.json()['request']))
    df_tmp = pd.DataFrame([(r1.json()['request']['avatar_id'],name)], columns=['avatar_id', 'name'])
    matrix_avatar = matrix_avatar.append(df_tmp)
            
                
pricing_requests = pd.concat(pricing_requests)
matrix_avatar_df = pd.DataFrame(matrix_avatar)
sub_matrix_9_part3 = pd.merge(pricing_requests,matrix_avatar_df)
sub_matrix_9_part3.to_csv('requests_9_part3.csv')
display(sub_matrix_9_part3)
# Out:
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
# C:\Users\teaca\AppData\Local\Temp\ipykernel_22236\3127666514.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matrix_avatar = matrix_avatar.append(df_tmp)
#        hotel_id  price  stock    city  date  language  mobile avatar_id  \
# 0           549    105     10  vienna    21  romanian       1    300211
# 1           549    105     10  vienna    21  romanian       1    300211
# 2           565    273     46  vienna    21  romanian       1    300211
# 3           565    273     46  vienna    21  romanian       1    300211
# 4            70    176     42  vienna    21  romanian       1    300211
# ...         ...    ...    ...     ...   ...       ...     ...       ...
# 36057       403    265     48  vienna    21   italian       1    300406
# 36058       239    295     37  vienna    21   italian       1    300406
# 36059       565    278     46  vienna    21   italian       1    300406
# 36060       511    153     67  vienna    21   italian       1    300406
# 36061       292    211     29  vienna    21   italian       1    300406
#
#                                                 name
# 0      avatar_d_portuguese_price_mean_villes_date_12
# 1      avatar_d_portuguese_price_mean_villes_date_12
# 2      avatar_d_portuguese_price_mean_villes_date_12
# 3      avatar_d_portuguese_price_mean_villes_date_12
# 4      avatar_d_portuguese_price_mean_villes_date_12
# ...                                              ...
# 36057  avatar_d_portuguese_price_mean_villes_date_12
# 36058  avatar_d_portuguese_price_mean_villes_date_12
# 36059  avatar_d_portuguese_price_mean_villes_date_12
# 36060  avatar_d_portuguese_price_mean_villes_date_12
# 36061  avatar_d_portuguese_price_mean_villes_date_12
#
# [36062 rows x 9 columns]
